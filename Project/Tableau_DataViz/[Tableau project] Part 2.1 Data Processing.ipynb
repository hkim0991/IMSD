# %% [markdown]
# # 1. Load the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

print(os.getcwd())
os.chdir('C:/Users/kimi/Desktop/IMSD/Cours/Tableau/project')
# Out:
# C:\Users\kimi\Documents\Data_Analysis\IMSD_projets\Projet_Tableau

# %% [markdown]
# # 2. Load the dataset

# %%
data_path = "./data/airline_satisfaction.csv"

data = pd.read_csv(data_path, engine='python')

data.shape
data.head()
# Out:
#   satisfaction membership_status  age age_range  gender  price_sensitivity  \
# 0          4.5              Blue   31     30-39    Male                  1
# 1            4              Blue   56     50-59    Male                  2
# 2          2.5              Blue   21     20-29  Female                  2
# 3            4              Blue   43     40-49    Male                  1
# 4            5            Silver   49     40-49    Male                  1
#
#    first_flight_year  no_of_flights_p.a. no_of_flights_p.a._grouped  \
# 0               2007                  28                   21 to 30
# 1               2006                  41                   41 to 50
# 2               2006                   8                    1 to 10
# 3               2007                   9                    1 to 10
# 4               2006                  14                   11 to 20
#
#    percentage_of_flight_with_other_airlines             ...              \
# 0                                         7             ...
# 1                                         3             ...
# 2                                         7             ...
# 3                                         9             ...
# 4                                        10             ...
#
#   departure_state       destination_city  destination_state  \
# 0       Wisconsin  Dallas/Fort Worth, TX              Texas
# 1       Wisconsin  Dallas/Fort Worth, TX              Texas
# 2       Wisconsin  Dallas/Fort Worth, TX              Texas
# 3       Wisconsin  Dallas/Fort Worth, TX              Texas
# 4       Wisconsin  Dallas/Fort Worth, TX              Texas
#
#    scheduled_departure_hour departure_delay_in_mins  arrival_delay_in_mins  \
# 0                        15                     0.0                    3.0
# 1                        11                     2.0                    5.0
# 2                        12                    34.0                   14.0
# 3                        11                    26.0                   39.0
# 4                        12                     0.0                    0.0
#
#   flight_cancelled flight_time_in_mins flight_distance_in_miles  \
# 0               No               134.0                      821
# 1               No               120.0                      821
# 2               No               122.0                      853
# 3               No               141.0                      821
# 4               No               144.0                      853
#
#   arrival_delay_greater_5mins
# 0                          no
# 1                          no
# 2                         yes
# 3                         yes
# 4                          no
#
# [5 rows x 30 columns]

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129889 entries, 0 to 129888
# Data columns (total 30 columns):
# satisfaction                                129889 non-null object
# membership_status                           129889 non-null object
# age                                         129889 non-null int64
# age_range                                   129889 non-null object
# gender                                      129889 non-null object
# price_sensitivity                           129889 non-null int64
# first_flight_year                           129889 non-null int64
# no_of_flights_p.a.                          129889 non-null int64
# no_of_flights_p.a._grouped                  129889 non-null object
# percentage_of_flight_with_other_airlines    129889 non-null int64
# travel_type                                 129889 non-null object
# no_of_other_loyalty_cards                   129889 non-null int64
# shopping_amount_at_airport                  129889 non-null int64
# eating_and_drinking_at_airport              129889 non-null int64
# cabin_class                                 129889 non-null object
# day_of_month                                129889 non-null int64
# flight_date                                 129889 non-null object
# airline_code                                129889 non-null object
# airline_name                                129889 non-null object
# departure_city                              129889 non-null object
# departure_state                             129889 non-null object
# destination_city                            129889 non-null object
# destination_state                           129889 non-null object
# scheduled_departure_hour                    129889 non-null int64
# departure_delay_in_mins                     127544 non-null float64
# arrival_delay_in_mins                       127151 non-null float64
# flight_cancelled                            129889 non-null object
# flight_time_in_mins                         127151 non-null float64
# flight_distance_in_miles                    129889 non-null int64
# arrival_delay_greater_5mins                 129889 non-null object
# dtypes: float64(3), int64(11), object(16)
# memory usage: 29.7+ MB
#                  age  price_sensitivity  first_flight_year  \
# count  129889.000000      129889.000000      129889.000000
# mean       46.196221           1.275504        2007.208509
# std        17.321014           0.546355           2.976945
# min        15.000000           0.000000        2003.000000
# 25%        33.000000           1.000000        2004.000000
# 50%        45.000000           1.000000        2007.000000
# 75%        59.000000           2.000000        2010.000000
# max        85.000000           5.000000        2012.000000
#
#        no_of_flights_p.a.  percentage_of_flight_with_other_airlines  \
# count       129889.000000                             129889.000000
# mean            20.078744                                  9.313853
# std             14.380254                                  8.761000
# min              0.000000                                  1.000000
# 25%              9.000000                                  4.000000
# 50%             17.000000                                  7.000000
# 75%             29.000000                                 10.000000
# max            100.000000                                110.000000
#
#        no_of_other_loyalty_cards  shopping_amount_at_airport  \
# count              129889.000000               129889.000000
# mean                    0.883785                   26.553403
# std                     1.142234                   53.081107
# min                     0.000000                    0.000000
# 25%                     0.000000                    0.000000
# 50%                     0.000000                    0.000000
# 75%                     2.000000                   30.000000
# max                    12.000000                  879.000000
#
#        eating_and_drinking_at_airport   day_of_month  \
# count                   129889.000000  129889.000000
# mean                        68.241883      15.723133
# std                         52.210116       8.658843
# min                          0.000000       1.000000
# 25%                         30.000000       8.000000
# 50%                         60.000000      16.000000
# 75%                         90.000000      23.000000
# max                        895.000000      31.000000
#
#        scheduled_departure_hour  departure_delay_in_mins  \
# count             129889.000000            127544.000000
# mean                  12.986003                14.983778
# std                    4.622736                38.365649
# min                    1.000000                 0.000000
# 25%                    9.000000                 0.000000
# 50%                   13.000000                 0.000000
# 75%                   17.000000                13.000000
# max                   23.000000              1592.000000
#
#        arrival_delay_in_mins  flight_time_in_mins  flight_distance_in_miles
# count          127151.000000        127151.000000             129889.000000
# mean               15.368695           111.514325                793.803740
# std                38.762414            71.775896                592.125457
# min                 0.000000             8.000000                 31.000000
# 25%                 0.000000            59.000000                362.000000
# 50%                 0.000000            92.000000                630.000000
# 75%                13.000000           142.000000               1024.000000
# max              1584.000000           669.000000               4983.000000

# %% [markdown]
# # 3. Data Cleaning

# %% [markdown]
# ## 3.1 Missing Values

# %%
data.isnull().sum()
# Out:
# satisfaction                                   0
# membership_status                              0
# age                                            0
# age_range                                      0
# gender                                         0
# price_sensitivity                              0
# first_flight_year                              0
# no_of_flights_p.a.                             0
# no_of_flights_p.a._grouped                     0
# percentage_of_flight_with_other_airlines       0
# travel_type                                    0
# no_of_other_loyalty_cards                      0
# shopping_amount_at_airport                     0
# eating_and_drinking_at_airport                 0
# cabin_class                                    0
# day_of_month                                   0
# flight_date                                    0
# airline_code                                   0
# airline_name                                   0
# departure_city                                 0
# departure_state                                0
# destination_city                               0
# destination_state                              0
# scheduled_departure_hour                       0
# departure_delay_in_mins                     2345
# arrival_delay_in_mins                       2738
# flight_cancelled                               0
# flight_time_in_mins                         2738
# flight_distance_in_miles                       0
# arrival_delay_greater_5mins                    0
# dtype: int64

# %%
# variable 'departure_delay_in_mins'
nan_rows = data[data['departure_delay_in_mins'].isnull()] # in order to see other remarable points among other variables
nan_rows

# It seems like many of rows where missing values are have 'Yes' in 'flight_cancelled' variable
# that is why we don't have any info on 'departure_delay_in_mins', 'arrival_delay_in_mins' and 'flight_time_in_mins'
# Out:
#        satisfaction membership_status  age age_range  gender  \
# 70                3              Blue   43     40-49  Female
# 131               3              Blue   31     30-39  Female
# 159               3            Silver   38     30-39  Female
# 161               4              Gold   46     40-49  Female
# 177               4              Blue   36     30-39    Male
# 228               3              Blue   18      0-19    Male
# 230               2              Blue   79     70-79    Male
# 442               3              Blue   17      0-19  Female
# 870               3              Gold   73     70-79    Male
# 877               3            Silver   31     30-39  Female
# 945               4              Blue   21     20-29  Female
# 960               3            Silver   41     40-49  Female
# 962               4              Blue   20     20-29  Female
# 974               4              Blue   57     50-59    Male
# 979               2              Blue   43     40-49    Male
# 982               3              Blue   36     30-39  Female
# 1205              2              Blue   36     30-39  Female
# 1223              3              Blue   17      0-19  Female
# 1238              3              Blue   53     50-59    Male
# 1263              3              Blue   63     60-69    Male
# 1270              3              Blue   75     70-79  Female
# 1292              2              Blue   22     20-29  Female
# 1293              4            Silver   39     30-39  Female
# 1299              2              Blue   60     60-69    Male
# 1304              2              Blue   73     70-79  Female
# 1373              4              Blue   20     20-29  Female
# 1472              2              Blue   74     70-79  Female
# 1607              3              Blue   26     20-29  Female
# 1640              3              Blue   35     30-39  Female
# 1670              3              Blue   77     70-79  Female
# ...             ...               ...  ...       ...     ...
# 125081            4              Blue   17      0-19    Male
# 125105            3              Blue   31     30-39    Male
# 125212            3              Blue   51     50-59    Male
# 125232            2              Gold   37     30-39  Female
# 125257            3              Blue   54     50-59  Female
# 125262            3              Blue   51     50-59    Male
# 125355            4            Silver   25     20-29  Female
# 125365            4              Blue   18      0-19    Male
# 125675            4              Blue   44     40-49    Male
# 125694            4              Blue   58     50-59    Male
# 125731            2              Blue   63     60-69  Female
# 125877            4            Silver   36     30-39    Male
# 126191            3              Gold   52     50-59    Male
# 126219            4            Silver   65     60-69    Male
# 126253            4              Blue   39     30-39  Female
# 126315            2              Blue   23     20-29  Female
# 126381            1              Blue   55     50-59  Female
# 126529            4              Blue   17      0-19  Female
# 126578            3            Silver   40     40-49    Male
# 126584            5            Silver   46     40-49  Female
# 126744            3              Blue   17      0-19  Female
# 126882            3              Blue   80       80+  Female
# 126911            2              Blue   59     50-59  Female
# 127444            3              Blue   80       80+  Female
# 127687            3              Gold   78     70-79    Male
# 127950            3              Blue   36     30-39    Male
# 128113            3              Blue   36     30-39  Female
# 128134            3              Blue   63     60-69  Female
# 128565            4              Blue   56     50-59  Female
# 128922            2              Gold   68     60-69  Female
#
#         price_sensitivity  first_flight_year  no_of_flights_p.a.  \
# 70                      1               2003                  21
# 131                     1               2005                  43
# 159                     1               2005                  13
# 161                     1               2010                   5
# 177                     2               2010                  31
# 228                     2               2003                  38
# 230                     1               2006                  16
# 442                     2               2008                  19
# 870                     2               2004                  28
# 877                     1               2011                   5
# 945                     2               2012                   8
# 960                     1               2004                  15
# 962                     1               2010                  21
# 974                     1               2003                   4
# 979                     1               2011                   1
# 982                     2               2007                   8
# 1205                    1               2005                  28
# 1223                    1               2006                  13
# 1238                    2               2007                  31
# 1263                    1               2004                   8
# 1270                    1               2005                  33
# 1292                    1               2010                   2
# 1293                    1               2010                  34
# 1299                    2               2008                  26
# 1304                    1               2011                  13
# 1373                    2               2010                  11
# 1472                    2               2011                  39
# 1607                    1               2005                  31
# 1640                    2               2003                   8
# 1670                    1               2007                  16
# ...                   ...                ...                 ...
# 125081                  2               2005                  11
# 125105                  1               2003                  43
# 125212                  1               2011                  23
# 125232                  1               2012                  17
# 125257                  1               2006                   8
# 125262                  1               2004                  62
# 125355                  1               2003                   6
# 125365                  1               2012                  35
# 125675                  1               2008                  26
# 125694                  1               2003                  21
# 125731                  2               2004                  17
# 125877                  1               2003                  18
# 126191                  1               2006                  15
# 126219                  1               2004                  17
# 126253                  1               2005                  23
# 126315                  1               2012                  18
# 126381                  1               2012                  31
# 126529                  2               2005                   0
# 126578                  1               2009                  33
# 126584                  1               2008                  10
# 126744                  1               2004                   8
# 126882                  1               2009                  17
# 126911                  2               2008                   8
# 127444                  1               2003                  45
# 127687                  1               2009                  53
# 127950                  1               2006                  10
# 128113                  1               2011                  27
# 128134                  1               2008                  21
# 128565                  1               2008                  30
# 128922                  1               2006                  18
#
#        no_of_flights_p.a._grouped  percentage_of_flight_with_other_airlines  \
# 70                       21 to 30                                         4
# 131                      41 to 50                                         5
# 159                      11 to 20                                         8
# 161                       1 to 10                                        32
# 177                      31 to 40                                         3
# 228                      31 to 40                                         2
# 230                      11 to 20                                         7
# 442                      11 to 20                                        18
# 870                      21 to 30                                         8
# 877                       1 to 10                                         6
# 945                       1 to 10                                         8
# 960                      11 to 20                                        45
# 962                      21 to 30                                        50
# 974                       1 to 10                                         4
# 979                       1 to 10                                         8
# 982                       1 to 10                                        18
# 1205                     21 to 30                                        25
# 1223                     11 to 20                                         5
# 1238                     31 to 40                                         1
# 1263                      1 to 10                                        10
# 1270                     31 to 40                                         4
# 1292                      1 to 10                                        37
# 1293                     31 to 40                                        10
# 1299                     21 to 30                                         4
# 1304                     11 to 20                                         4
# 1373                     11 to 20                                         3
# 1472                     31 to 40                                         9
# 1607                     31 to 40                                        25
# 1640                      1 to 10                                        18
# 1670                     11 to 20                                         6
# ...                           ...                                       ...
# 125081                   11 to 20                                         2
# 125105                   41 to 50                                         2
# 125212                   21 to 30                                         9
# 125232                   11 to 20                                        16
# 125257                    1 to 10                                        10
# 125262                   61 to 70                                         1
# 125355                    1 to 10                                        40
# 125365                   31 to 40                                         5
# 125675                   21 to 30                                         2
# 125694                   21 to 30                                         5
# 125731                   11 to 20                                         5
# 125877                   11 to 20                                         4
# 126191                   11 to 20                                         1
# 126219                   11 to 20                                         8
# 126253                   21 to 30                                         4
# 126315                   11 to 20                                        22
# 126381                   31 to 40                                         8
# 126529                          0                                         6
# 126578                   31 to 40                                        31
# 126584                   11 to 20                                        10
# 126744                    1 to 10                                         6
# 126882                   11 to 20                                         7
# 126911                    1 to 10                                         4
# 127444                   41 to 50                                         3
# 127687                   51 to 60                                         6
# 127950                   11 to 20                                         6
# 128113                   21 to 30                                        17
# 128134                   21 to 30                                         2
# 128565                   31 to 40                                         4
# 128922                   11 to 20                                         2
#
#                    ...             departure_state           destination_city  \
# 70                 ...                   Wisconsin                Chicago, IL
# 131                ...                    Virginia              Nashville, TN
# 159                ...                    Virginia         Raleigh/Durham, NC
# 161                ...                    Virginia         Raleigh/Durham, NC
# 177                ...                    Virginia         Raleigh/Durham, NC
# 228                ...                    Virginia               New York, NY
# 230                ...                    Virginia               New York, NY
# 442                ...                       Texas      Dallas/Fort Worth, TX
# 870                ...                       Texas          Wichita Falls, TX
# 877                ...                       Texas      Dallas/Fort Worth, TX
# 945                ...                       Texas               Longview, TX
# 960                ...                       Texas      Dallas/Fort Worth, TX
# 962                ...                       Texas      Dallas/Fort Worth, TX
# 974                ...                       Texas                Abilene, TX
# 979                ...                       Texas      Dallas/Fort Worth, TX
# 982                ...                       Texas      Dallas/Fort Worth, TX
# 1205               ...                       Texas                  Tyler, TX
# 1223               ...                       Texas      Dallas/Fort Worth, TX
# 1238               ...                       Texas      Dallas/Fort Worth, TX
# 1263               ...                       Texas      Dallas/Fort Worth, TX
# 1270               ...                       Texas      Dallas/Fort Worth, TX
# 1292               ...                       Texas                  Tyler, TX
# 1293               ...                       Texas      Dallas/Fort Worth, TX
# 1299               ...                       Texas      Dallas/Fort Worth, TX
# 1304               ...                       Texas      Dallas/Fort Worth, TX
# 1373               ...                       Texas      Dallas/Fort Worth, TX
# 1472               ...                       Texas              Knoxville, TN
# 1607               ...                       Texas       Lawton/Fort Sill, OK
# 1640               ...                       Texas  Greensboro/High Point, NC
# 1670               ...                       Texas               Santa Fe, NM
# ...                ...                         ...                        ...
# 125081             ...                    Maryland              Charlotte, NC
# 125105             ...                    Maryland              Charlotte, NC
# 125212             ...                   Louisiana              Charlotte, NC
# 125232             ...                   Louisiana              Charlotte, NC
# 125257             ...                     Indiana              Charlotte, NC
# 125262             ...                     Indiana              Charlotte, NC
# 125355             ...                    Illinois              Charlotte, NC
# 125365             ...                    Illinois              Charlotte, NC
# 125675             ...                     Florida             Washington, DC
# 125694             ...                     Florida             Washington, DC
# 125731             ...                     Florida             Washington, DC
# 125877             ...                     Florida           Philadelphia, PA
# 126191             ...                     Florida              Charlotte, NC
# 126219             ...                     Florida              Charlotte, NC
# 126253             ...                     Florida              Charlotte, NC
# 126315             ...                     Florida              Charlotte, NC
# 126381             ...                     Florida              Charlotte, NC
# 126529             ...                 Connecticut           Philadelphia, PA
# 126578             ...                    Colorado           Philadelphia, PA
# 126584             ...                    Colorado           Philadelphia, PA
# 126744             ...                  California           Philadelphia, PA
# 126882             ...                  California              Charlotte, NC
# 126911             ...                  California              Charlotte, NC
# 127444             ...                     Arizona      Dallas/Fort Worth, TX
# 127687             ...                     Arizona               New York, NY
# 127950             ...                     Arizona                 Boston, MA
# 128113             ...                     Arizona                Atlanta, GA
# 128134             ...                     Arizona                Atlanta, GA
# 128565             ...                     Arizona          San Francisco, CA
# 128922             ...                      Nevada               New York, NY
#
#         destination_state  scheduled_departure_hour departure_delay_in_mins  \
# 70               Illinois                         6                     NaN
# 131             Tennessee                        13                     NaN
# 159        North Carolina                         9                     NaN
# 161        North Carolina                        21                     NaN
# 177        North Carolina                         6                     NaN
# 228              New York                        14                     NaN
# 230              New York                        10                     NaN
# 442                 Texas                        11                     NaN
# 870                 Texas                         9                     NaN
# 877                 Texas                        10                     NaN
# 945                 Texas                        16                     NaN
# 960                 Texas                        11                     NaN
# 962                 Texas                        10                     NaN
# 974                 Texas                        10                     NaN
# 979                 Texas                        14                     NaN
# 982                 Texas                        12                     NaN
# 1205                Texas                         9                     NaN
# 1223                Texas                         9                     NaN
# 1238                Texas                        14                     NaN
# 1263                Texas                        11                     NaN
# 1270                Texas                        11                     NaN
# 1292                Texas                        14                     NaN
# 1293                Texas                        11                     NaN
# 1299                Texas                        17                     NaN
# 1304                Texas                         9                     NaN
# 1373                Texas                        11                     NaN
# 1472            Tennessee                        20                     NaN
# 1607             Oklahoma                        11                     NaN
# 1640       North Carolina                        19                     NaN
# 1670           New Mexico                        16                     NaN
# ...                   ...                       ...                     ...
# 125081     North Carolina                        19                     NaN
# 125105     North Carolina                        12                     NaN
# 125212     North Carolina                        12                     NaN
# 125232     North Carolina                        12                     NaN
# 125257     North Carolina                         6                     NaN
# 125262     North Carolina                         6                     NaN
# 125355     North Carolina                         5                     NaN
# 125365     North Carolina                        18                     NaN
# 125675           Virginia                        14                     NaN
# 125694           Virginia                        14                     NaN
# 125731           Virginia                         8                     NaN
# 125877       Pennsylvania                        19                     NaN
# 126191     North Carolina                        13                     NaN
# 126219     North Carolina                        19                     NaN
# 126253     North Carolina                        17                     NaN
# 126315     North Carolina                         5                     NaN
# 126381     North Carolina                         6                     NaN
# 126529       Pennsylvania                         7                     NaN
# 126578       Pennsylvania                         1                     NaN
# 126584       Pennsylvania                         7                     NaN
# 126744       Pennsylvania                         8                     NaN
# 126882     North Carolina                         9                     NaN
# 126911     North Carolina                        11                     NaN
# 127444              Texas                         8                     NaN
# 127687           New York                        13                     NaN
# 127950      Massachusetts                         5                     NaN
# 128113            Georgia                        10                     NaN
# 128134            Georgia                        16                     NaN
# 128565         California                        18                     NaN
# 128922           New York                        14                     NaN
#
#         arrival_delay_in_mins flight_cancelled flight_time_in_mins  \
# 70                        NaN              Yes                 NaN
# 131                       NaN              Yes                 NaN
# 159                       NaN              Yes                 NaN
# 161                       NaN              Yes                 NaN
# 177                       NaN              Yes                 NaN
# 228                       NaN              Yes                 NaN
# 230                       NaN              Yes                 NaN
# 442                       NaN              Yes                 NaN
# 870                       NaN              Yes                 NaN
# 877                       NaN              Yes                 NaN
# 945                       NaN              Yes                 NaN
# 960                       NaN              Yes                 NaN
# 962                       NaN              Yes                 NaN
# 974                       NaN              Yes                 NaN
# 979                       NaN              Yes                 NaN
# 982                       NaN              Yes                 NaN
# 1205                      NaN              Yes                 NaN
# 1223                      NaN              Yes                 NaN
# 1238                      NaN              Yes                 NaN
# 1263                      NaN              Yes                 NaN
# 1270                      NaN              Yes                 NaN
# 1292                      NaN              Yes                 NaN
# 1293                      NaN              Yes                 NaN
# 1299                      NaN              Yes                 NaN
# 1304                      NaN              Yes                 NaN
# 1373                      NaN              Yes                 NaN
# 1472                      NaN              Yes                 NaN
# 1607                      NaN              Yes                 NaN
# 1640                      NaN              Yes                 NaN
# 1670                      NaN              Yes                 NaN
# ...                       ...              ...                 ...
# 125081                    NaN              Yes                 NaN
# 125105                    NaN              Yes                 NaN
# 125212                    NaN              Yes                 NaN
# 125232                    NaN              Yes                 NaN
# 125257                    NaN              Yes                 NaN
# 125262                    NaN              Yes                 NaN
# 125355                    NaN              Yes                 NaN
# 125365                    NaN              Yes                 NaN
# 125675                    NaN              Yes                 NaN
# 125694                    NaN              Yes                 NaN
# 125731                    NaN              Yes                 NaN
# 125877                    NaN              Yes                 NaN
# 126191                    NaN              Yes                 NaN
# 126219                    NaN              Yes                 NaN
# 126253                    NaN              Yes                 NaN
# 126315                    NaN              Yes                 NaN
# 126381                    NaN              Yes                 NaN
# 126529                    NaN              Yes                 NaN
# 126578                    NaN              Yes                 NaN
# 126584                    NaN              Yes                 NaN
# 126744                    NaN              Yes                 NaN
# 126882                    NaN              Yes                 NaN
# 126911                    NaN              Yes                 NaN
# 127444                    NaN              Yes                 NaN
# 127687                    NaN              Yes                 NaN
# 127950                    NaN              Yes                 NaN
# 128113                    NaN              Yes                 NaN
# 128134                    NaN              Yes                 NaN
# 128565                    NaN              Yes                 NaN
# 128922                    NaN              Yes                 NaN
#
#        flight_distance_in_miles arrival_delay_greater_5mins
# 70                          173                          no
# 131                         562                          no
# 159                         227                          no
# 161                         227                          no
# 177                         227                          no
# 228                         290                          no
# 230                         213                          no
# 442                         396                          no
# 870                         113                          no
# 877                         229                          no
# 945                         140                          no
# 960                          89                          no
# 962                         102                          no
# 974                         158                          no
# 979                         312                          no
# 982                         134                          no
# 1205                        102                          no
# 1223                        134                          no
# 1238                        158                          no
# 1263                        113                          no
# 1270                        396                          no
# 1292                        102                          no
# 1293                        158                          no
# 1299                        113                          no
# 1304                        164                          no
# 1373                        113                          no
# 1472                        772                          no
# 1607                        140                          no
# 1640                        999                          no
# 1670                        551                          no
# ...                         ...                         ...
# 125081                      361                          no
# 125105                      361                          no
# 125212                      651                          no
# 125232                      651                          no
# 125257                      427                          no
# 125262                      427                          no
# 125355                      599                          no
# 125365                      599                          no
# 125675                      759                          no
# 125694                      814                          no
# 125731                      759                          no
# 125877                      920                          no
# 126191                      507                          no
# 126219                      600                          no
# 126253                      328                          no
# 126315                      468                          no
# 126381                      600                          no
# 126529                      196                          no
# 126578                     1558                          no
# 126584                     1558                          no
# 126744                     2521                          no
# 126882                     2125                          no
# 126911                     2077                          no
# 127444                      868                          no
# 127687                     2153                          no
# 127950                     2300                          no
# 128113                     1587                          no
# 128134                     1587                          no
# 128565                      651                          no
# 128922                     2248                          no
#
# [2345 rows x 30 columns]

# %%
data[data['flight_cancelled'] == 'Yes'].count()

# When a flight has cancelled, we don't have any value in 'arrival_delay_in_mins' and 'flight_time_in_mins'
# but in 'departure_delay_in_mins', there are 56 which have value in 'departure_delay_in_mins'
# Out:
# satisfaction                                2401
# membership_status                           2401
# age                                         2401
# age_range                                   2401
# gender                                      2401
# price_sensitivity                           2401
# first_flight_year                           2401
# no_of_flights_p.a.                          2401
# no_of_flights_p.a._grouped                  2401
# percentage_of_flight_with_other_airlines    2401
# travel_type                                 2401
# no_of_other_loyalty_cards                   2401
# shopping_amount_at_airport                  2401
# eating_and_drinking_at_airport              2401
# cabin_class                                 2401
# day_of_month                                2401
# flight_date                                 2401
# airline_code                                2401
# airline_name                                2401
# departure_city                              2401
# departure_state                             2401
# destination_city                            2401
# destination_state                           2401
# scheduled_departure_hour                    2401
# departure_delay_in_mins                       56
# arrival_delay_in_mins                          0
# flight_cancelled                            2401
# flight_time_in_mins                            0
# flight_distance_in_miles                    2401
# arrival_delay_greater_5mins                 2401
# dtype: int64

# %%
data.loc[(data['flight_cancelled'] == 'Yes') 
         & (data['departure_delay_in_mins'].isnull()) 
         & (data['arrival_delay_in_mins'].isnull()) 
         & (data['flight_time_in_mins'].isnull())]

# 2345/2401 flights are cancelled before the scheduled flight time
# Out:
#        satisfaction membership_status  age age_range  gender  \
# 70                3              Blue   43     40-49  Female
# 131               3              Blue   31     30-39  Female
# 159               3            Silver   38     30-39  Female
# 161               4              Gold   46     40-49  Female
# 177               4              Blue   36     30-39    Male
# 228               3              Blue   18      0-19    Male
# 230               2              Blue   79     70-79    Male
# 442               3              Blue   17      0-19  Female
# 870               3              Gold   73     70-79    Male
# 877               3            Silver   31     30-39  Female
# 945               4              Blue   21     20-29  Female
# 960               3            Silver   41     40-49  Female
# 962               4              Blue   20     20-29  Female
# 974               4              Blue   57     50-59    Male
# 979               2              Blue   43     40-49    Male
# 982               3              Blue   36     30-39  Female
# 1205              2              Blue   36     30-39  Female
# 1223              3              Blue   17      0-19  Female
# 1238              3              Blue   53     50-59    Male
# 1263              3              Blue   63     60-69    Male
# 1270              3              Blue   75     70-79  Female
# 1292              2              Blue   22     20-29  Female
# 1293              4            Silver   39     30-39  Female
# 1299              2              Blue   60     60-69    Male
# 1304              2              Blue   73     70-79  Female
# 1373              4              Blue   20     20-29  Female
# 1472              2              Blue   74     70-79  Female
# 1607              3              Blue   26     20-29  Female
# 1640              3              Blue   35     30-39  Female
# 1670              3              Blue   77     70-79  Female
# ...             ...               ...  ...       ...     ...
# 125081            4              Blue   17      0-19    Male
# 125105            3              Blue   31     30-39    Male
# 125212            3              Blue   51     50-59    Male
# 125232            2              Gold   37     30-39  Female
# 125257            3              Blue   54     50-59  Female
# 125262            3              Blue   51     50-59    Male
# 125355            4            Silver   25     20-29  Female
# 125365            4              Blue   18      0-19    Male
# 125675            4              Blue   44     40-49    Male
# 125694            4              Blue   58     50-59    Male
# 125731            2              Blue   63     60-69  Female
# 125877            4            Silver   36     30-39    Male
# 126191            3              Gold   52     50-59    Male
# 126219            4            Silver   65     60-69    Male
# 126253            4              Blue   39     30-39  Female
# 126315            2              Blue   23     20-29  Female
# 126381            1              Blue   55     50-59  Female
# 126529            4              Blue   17      0-19  Female
# 126578            3            Silver   40     40-49    Male
# 126584            5            Silver   46     40-49  Female
# 126744            3              Blue   17      0-19  Female
# 126882            3              Blue   80       80+  Female
# 126911            2              Blue   59     50-59  Female
# 127444            3              Blue   80       80+  Female
# 127687            3              Gold   78     70-79    Male
# 127950            3              Blue   36     30-39    Male
# 128113            3              Blue   36     30-39  Female
# 128134            3              Blue   63     60-69  Female
# 128565            4              Blue   56     50-59  Female
# 128922            2              Gold   68     60-69  Female
#
#         price_sensitivity  first_flight_year  no_of_flights_p.a.  \
# 70                      1               2003                  21
# 131                     1               2005                  43
# 159                     1               2005                  13
# 161                     1               2010                   5
# 177                     2               2010                  31
# 228                     2               2003                  38
# 230                     1               2006                  16
# 442                     2               2008                  19
# 870                     2               2004                  28
# 877                     1               2011                   5
# 945                     2               2012                   8
# 960                     1               2004                  15
# 962                     1               2010                  21
# 974                     1               2003                   4
# 979                     1               2011                   1
# 982                     2               2007                   8
# 1205                    1               2005                  28
# 1223                    1               2006                  13
# 1238                    2               2007                  31
# 1263                    1               2004                   8
# 1270                    1               2005                  33
# 1292                    1               2010                   2
# 1293                    1               2010                  34
# 1299                    2               2008                  26
# 1304                    1               2011                  13
# 1373                    2               2010                  11
# 1472                    2               2011                  39
# 1607                    1               2005                  31
# 1640                    2               2003                   8
# 1670                    1               2007                  16
# ...                   ...                ...                 ...
# 125081                  2               2005                  11
# 125105                  1               2003                  43
# 125212                  1               2011                  23
# 125232                  1               2012                  17
# 125257                  1               2006                   8
# 125262                  1               2004                  62
# 125355                  1               2003                   6
# 125365                  1               2012                  35
# 125675                  1               2008                  26
# 125694                  1               2003                  21
# 125731                  2               2004                  17
# 125877                  1               2003                  18
# 126191                  1               2006                  15
# 126219                  1               2004                  17
# 126253                  1               2005                  23
# 126315                  1               2012                  18
# 126381                  1               2012                  31
# 126529                  2               2005                   0
# 126578                  1               2009                  33
# 126584                  1               2008                  10
# 126744                  1               2004                   8
# 126882                  1               2009                  17
# 126911                  2               2008                   8
# 127444                  1               2003                  45
# 127687                  1               2009                  53
# 127950                  1               2006                  10
# 128113                  1               2011                  27
# 128134                  1               2008                  21
# 128565                  1               2008                  30
# 128922                  1               2006                  18
#
#        no_of_flights_p.a._grouped  percentage_of_flight_with_other_airlines  \
# 70                       21 to 30                                         4
# 131                      41 to 50                                         5
# 159                      11 to 20                                         8
# 161                       1 to 10                                        32
# 177                      31 to 40                                         3
# 228                      31 to 40                                         2
# 230                      11 to 20                                         7
# 442                      11 to 20                                        18
# 870                      21 to 30                                         8
# 877                       1 to 10                                         6
# 945                       1 to 10                                         8
# 960                      11 to 20                                        45
# 962                      21 to 30                                        50
# 974                       1 to 10                                         4
# 979                       1 to 10                                         8
# 982                       1 to 10                                        18
# 1205                     21 to 30                                        25
# 1223                     11 to 20                                         5
# 1238                     31 to 40                                         1
# 1263                      1 to 10                                        10
# 1270                     31 to 40                                         4
# 1292                      1 to 10                                        37
# 1293                     31 to 40                                        10
# 1299                     21 to 30                                         4
# 1304                     11 to 20                                         4
# 1373                     11 to 20                                         3
# 1472                     31 to 40                                         9
# 1607                     31 to 40                                        25
# 1640                      1 to 10                                        18
# 1670                     11 to 20                                         6
# ...                           ...                                       ...
# 125081                   11 to 20                                         2
# 125105                   41 to 50                                         2
# 125212                   21 to 30                                         9
# 125232                   11 to 20                                        16
# 125257                    1 to 10                                        10
# 125262                   61 to 70                                         1
# 125355                    1 to 10                                        40
# 125365                   31 to 40                                         5
# 125675                   21 to 30                                         2
# 125694                   21 to 30                                         5
# 125731                   11 to 20                                         5
# 125877                   11 to 20                                         4
# 126191                   11 to 20                                         1
# 126219                   11 to 20                                         8
# 126253                   21 to 30                                         4
# 126315                   11 to 20                                        22
# 126381                   31 to 40                                         8
# 126529                          0                                         6
# 126578                   31 to 40                                        31
# 126584                   11 to 20                                        10
# 126744                    1 to 10                                         6
# 126882                   11 to 20                                         7
# 126911                    1 to 10                                         4
# 127444                   41 to 50                                         3
# 127687                   51 to 60                                         6
# 127950                   11 to 20                                         6
# 128113                   21 to 30                                        17
# 128134                   21 to 30                                         2
# 128565                   31 to 40                                         4
# 128922                   11 to 20                                         2
#
#                    ...             departure_state           destination_city  \
# 70                 ...                   Wisconsin                Chicago, IL
# 131                ...                    Virginia              Nashville, TN
# 159                ...                    Virginia         Raleigh/Durham, NC
# 161                ...                    Virginia         Raleigh/Durham, NC
# 177                ...                    Virginia         Raleigh/Durham, NC
# 228                ...                    Virginia               New York, NY
# 230                ...                    Virginia               New York, NY
# 442                ...                       Texas      Dallas/Fort Worth, TX
# 870                ...                       Texas          Wichita Falls, TX
# 877                ...                       Texas      Dallas/Fort Worth, TX
# 945                ...                       Texas               Longview, TX
# 960                ...                       Texas      Dallas/Fort Worth, TX
# 962                ...                       Texas      Dallas/Fort Worth, TX
# 974                ...                       Texas                Abilene, TX
# 979                ...                       Texas      Dallas/Fort Worth, TX
# 982                ...                       Texas      Dallas/Fort Worth, TX
# 1205               ...                       Texas                  Tyler, TX
# 1223               ...                       Texas      Dallas/Fort Worth, TX
# 1238               ...                       Texas      Dallas/Fort Worth, TX
# 1263               ...                       Texas      Dallas/Fort Worth, TX
# 1270               ...                       Texas      Dallas/Fort Worth, TX
# 1292               ...                       Texas                  Tyler, TX
# 1293               ...                       Texas      Dallas/Fort Worth, TX
# 1299               ...                       Texas      Dallas/Fort Worth, TX
# 1304               ...                       Texas      Dallas/Fort Worth, TX
# 1373               ...                       Texas      Dallas/Fort Worth, TX
# 1472               ...                       Texas              Knoxville, TN
# 1607               ...                       Texas       Lawton/Fort Sill, OK
# 1640               ...                       Texas  Greensboro/High Point, NC
# 1670               ...                       Texas               Santa Fe, NM
# ...                ...                         ...                        ...
# 125081             ...                    Maryland              Charlotte, NC
# 125105             ...                    Maryland              Charlotte, NC
# 125212             ...                   Louisiana              Charlotte, NC
# 125232             ...                   Louisiana              Charlotte, NC
# 125257             ...                     Indiana              Charlotte, NC
# 125262             ...                     Indiana              Charlotte, NC
# 125355             ...                    Illinois              Charlotte, NC
# 125365             ...                    Illinois              Charlotte, NC
# 125675             ...                     Florida             Washington, DC
# 125694             ...                     Florida             Washington, DC
# 125731             ...                     Florida             Washington, DC
# 125877             ...                     Florida           Philadelphia, PA
# 126191             ...                     Florida              Charlotte, NC
# 126219             ...                     Florida              Charlotte, NC
# 126253             ...                     Florida              Charlotte, NC
# 126315             ...                     Florida              Charlotte, NC
# 126381             ...                     Florida              Charlotte, NC
# 126529             ...                 Connecticut           Philadelphia, PA
# 126578             ...                    Colorado           Philadelphia, PA
# 126584             ...                    Colorado           Philadelphia, PA
# 126744             ...                  California           Philadelphia, PA
# 126882             ...                  California              Charlotte, NC
# 126911             ...                  California              Charlotte, NC
# 127444             ...                     Arizona      Dallas/Fort Worth, TX
# 127687             ...                     Arizona               New York, NY
# 127950             ...                     Arizona                 Boston, MA
# 128113             ...                     Arizona                Atlanta, GA
# 128134             ...                     Arizona                Atlanta, GA
# 128565             ...                     Arizona          San Francisco, CA
# 128922             ...                      Nevada               New York, NY
#
#         destination_state  scheduled_departure_hour departure_delay_in_mins  \
# 70               Illinois                         6                     NaN
# 131             Tennessee                        13                     NaN
# 159        North Carolina                         9                     NaN
# 161        North Carolina                        21                     NaN
# 177        North Carolina                         6                     NaN
# 228              New York                        14                     NaN
# 230              New York                        10                     NaN
# 442                 Texas                        11                     NaN
# 870                 Texas                         9                     NaN
# 877                 Texas                        10                     NaN
# 945                 Texas                        16                     NaN
# 960                 Texas                        11                     NaN
# 962                 Texas                        10                     NaN
# 974                 Texas                        10                     NaN
# 979                 Texas                        14                     NaN
# 982                 Texas                        12                     NaN
# 1205                Texas                         9                     NaN
# 1223                Texas                         9                     NaN
# 1238                Texas                        14                     NaN
# 1263                Texas                        11                     NaN
# 1270                Texas                        11                     NaN
# 1292                Texas                        14                     NaN
# 1293                Texas                        11                     NaN
# 1299                Texas                        17                     NaN
# 1304                Texas                         9                     NaN
# 1373                Texas                        11                     NaN
# 1472            Tennessee                        20                     NaN
# 1607             Oklahoma                        11                     NaN
# 1640       North Carolina                        19                     NaN
# 1670           New Mexico                        16                     NaN
# ...                   ...                       ...                     ...
# 125081     North Carolina                        19                     NaN
# 125105     North Carolina                        12                     NaN
# 125212     North Carolina                        12                     NaN
# 125232     North Carolina                        12                     NaN
# 125257     North Carolina                         6                     NaN
# 125262     North Carolina                         6                     NaN
# 125355     North Carolina                         5                     NaN
# 125365     North Carolina                        18                     NaN
# 125675           Virginia                        14                     NaN
# 125694           Virginia                        14                     NaN
# 125731           Virginia                         8                     NaN
# 125877       Pennsylvania                        19                     NaN
# 126191     North Carolina                        13                     NaN
# 126219     North Carolina                        19                     NaN
# 126253     North Carolina                        17                     NaN
# 126315     North Carolina                         5                     NaN
# 126381     North Carolina                         6                     NaN
# 126529       Pennsylvania                         7                     NaN
# 126578       Pennsylvania                         1                     NaN
# 126584       Pennsylvania                         7                     NaN
# 126744       Pennsylvania                         8                     NaN
# 126882     North Carolina                         9                     NaN
# 126911     North Carolina                        11                     NaN
# 127444              Texas                         8                     NaN
# 127687           New York                        13                     NaN
# 127950      Massachusetts                         5                     NaN
# 128113            Georgia                        10                     NaN
# 128134            Georgia                        16                     NaN
# 128565         California                        18                     NaN
# 128922           New York                        14                     NaN
#
#         arrival_delay_in_mins flight_cancelled flight_time_in_mins  \
# 70                        NaN              Yes                 NaN
# 131                       NaN              Yes                 NaN
# 159                       NaN              Yes                 NaN
# 161                       NaN              Yes                 NaN
# 177                       NaN              Yes                 NaN
# 228                       NaN              Yes                 NaN
# 230                       NaN              Yes                 NaN
# 442                       NaN              Yes                 NaN
# 870                       NaN              Yes                 NaN
# 877                       NaN              Yes                 NaN
# 945                       NaN              Yes                 NaN
# 960                       NaN              Yes                 NaN
# 962                       NaN              Yes                 NaN
# 974                       NaN              Yes                 NaN
# 979                       NaN              Yes                 NaN
# 982                       NaN              Yes                 NaN
# 1205                      NaN              Yes                 NaN
# 1223                      NaN              Yes                 NaN
# 1238                      NaN              Yes                 NaN
# 1263                      NaN              Yes                 NaN
# 1270                      NaN              Yes                 NaN
# 1292                      NaN              Yes                 NaN
# 1293                      NaN              Yes                 NaN
# 1299                      NaN              Yes                 NaN
# 1304                      NaN              Yes                 NaN
# 1373                      NaN              Yes                 NaN
# 1472                      NaN              Yes                 NaN
# 1607                      NaN              Yes                 NaN
# 1640                      NaN              Yes                 NaN
# 1670                      NaN              Yes                 NaN
# ...                       ...              ...                 ...
# 125081                    NaN              Yes                 NaN
# 125105                    NaN              Yes                 NaN
# 125212                    NaN              Yes                 NaN
# 125232                    NaN              Yes                 NaN
# 125257                    NaN              Yes                 NaN
# 125262                    NaN              Yes                 NaN
# 125355                    NaN              Yes                 NaN
# 125365                    NaN              Yes                 NaN
# 125675                    NaN              Yes                 NaN
# 125694                    NaN              Yes                 NaN
# 125731                    NaN              Yes                 NaN
# 125877                    NaN              Yes                 NaN
# 126191                    NaN              Yes                 NaN
# 126219                    NaN              Yes                 NaN
# 126253                    NaN              Yes                 NaN
# 126315                    NaN              Yes                 NaN
# 126381                    NaN              Yes                 NaN
# 126529                    NaN              Yes                 NaN
# 126578                    NaN              Yes                 NaN
# 126584                    NaN              Yes                 NaN
# 126744                    NaN              Yes                 NaN
# 126882                    NaN              Yes                 NaN
# 126911                    NaN              Yes                 NaN
# 127444                    NaN              Yes                 NaN
# 127687                    NaN              Yes                 NaN
# 127950                    NaN              Yes                 NaN
# 128113                    NaN              Yes                 NaN
# 128134                    NaN              Yes                 NaN
# 128565                    NaN              Yes                 NaN
# 128922                    NaN              Yes                 NaN
#
#        flight_distance_in_miles arrival_delay_greater_5mins
# 70                          173                          no
# 131                         562                          no
# 159                         227                          no
# 161                         227                          no
# 177                         227                          no
# 228                         290                          no
# 230                         213                          no
# 442                         396                          no
# 870                         113                          no
# 877                         229                          no
# 945                         140                          no
# 960                          89                          no
# 962                         102                          no
# 974                         158                          no
# 979                         312                          no
# 982                         134                          no
# 1205                        102                          no
# 1223                        134                          no
# 1238                        158                          no
# 1263                        113                          no
# 1270                        396                          no
# 1292                        102                          no
# 1293                        158                          no
# 1299                        113                          no
# 1304                        164                          no
# 1373                        113                          no
# 1472                        772                          no
# 1607                        140                          no
# 1640                        999                          no
# 1670                        551                          no
# ...                         ...                         ...
# 125081                      361                          no
# 125105                      361                          no
# 125212                      651                          no
# 125232                      651                          no
# 125257                      427                          no
# 125262                      427                          no
# 125355                      599                          no
# 125365                      599                          no
# 125675                      759                          no
# 125694                      814                          no
# 125731                      759                          no
# 125877                      920                          no
# 126191                      507                          no
# 126219                      600                          no
# 126253                      328                          no
# 126315                      468                          no
# 126381                      600                          no
# 126529                      196                          no
# 126578                     1558                          no
# 126584                     1558                          no
# 126744                     2521                          no
# 126882                     2125                          no
# 126911                     2077                          no
# 127444                      868                          no
# 127687                     2153                          no
# 127950                     2300                          no
# 128113                     1587                          no
# 128134                     1587                          no
# 128565                      651                          no
# 128922                     2248                          no
#
# [2345 rows x 30 columns]

# %%
data.loc[(data['flight_cancelled'] == 'Yes') 
         & ~(data['departure_delay_in_mins'].isnull()) 
         & (data['arrival_delay_in_mins'].isnull()) 
         & (data['flight_time_in_mins'].isnull())]

# 56/2041 flights are cancelled after he scheduled filght time (meaning that people waited and the flight has been cancelled)
# Out:
#        satisfaction membership_status  age age_range  gender  \
# 249               3              Blue   19      0-19  Female
# 886               4              Blue   29     20-29  Female
# 1968              4              Blue   36     30-39  Female
# 2410              3              Blue   63     60-69  Female
# 2617              2              Blue   58     50-59  Female
# 3451              3              Blue   17      0-19  Female
# 3539              2              Blue   16      0-19  Female
# 3701              4              Blue   16      0-19    Male
# 3854              2              Blue   38     30-39  Female
# 5138              3              Blue   58     50-59    Male
# 7050              3              Blue   57     50-59  Female
# 7118              3              Blue   16      0-19    Male
# 8281              3              Blue   75     70-79  Female
# 9276              3            Silver   69     60-69  Female
# 12075             2              Blue   47     40-49  Female
# 13592             2              Blue   76     70-79  Female
# 17635             3              Blue   77     70-79    Male
# 18142             4              Blue   61     60-69  Female
# 19508             4            Silver   38     30-39    Male
# 19599             4            Silver   77     70-79    Male
# 19600             3              Blue   44     40-49  Female
# 20072             2              Blue   16      0-19  Female
# 20499             4              Blue   31     30-39    Male
# 26057             3              Blue   72     70-79    Male
# 27189             3              Blue   57     50-59  Female
# 29983             4              Blue   55     50-59    Male
# 39154             2              Blue   85       80+  Female
# 39533             2              Blue   85       80+  Female
# 40321             2              Blue   21     20-29    Male
# 41165             3              Blue   80       80+  Female
# 41929             4            Silver   58     50-59  Female
# 42381             2              Blue   38     30-39  Female
# 43051             4              Blue   21     20-29  Female
# 43066             3              Blue   16      0-19  Female
# 43811             3              Blue   78     70-79    Male
# 43947             3              Blue   58     50-59  Female
# 44825             4            Silver   27     20-29  Female
# 45027             3              Blue   31     30-39  Female
# 46588             4              Blue   29     20-29  Female
# 46994             3              Blue   56     50-59  Female
# 47410             4              Blue   25     20-29    Male
# 47982             3              Blue   21     20-29    Male
# 50965             3              Blue   15      0-19    Male
# 51366             3              Blue   51     50-59  Female
# 55455             3              Blue   78     70-79  Female
# 60041             3              Blue   68     60-69    Male
# 62097             3              Blue   61     60-69  Female
# 62907             4              Blue   47     40-49  Female
# 74771             3              Blue   60     60-69    Male
# 84003             4              Blue   65     60-69    Male
# 84030             2              Gold   69     60-69    Male
# 85867             3              Blue   74     70-79  Female
# 86934             2              Blue   78     70-79  Female
# 119962            2              Blue   74     70-79  Female
# 121036            2              Blue   16      0-19  Female
# 125406            4              Gold   41     40-49    Male
#
#         price_sensitivity  first_flight_year  no_of_flights_p.a.  \
# 249                     1               2005                  15
# 886                     2               2006                  18
# 1968                    2               2012                  33
# 2410                    1               2011                  50
# 2617                    0               2008                  81
# 3451                    2               2008                  13
# 3539                    0               2010                   8
# 3701                    1               2010                   4
# 3854                    1               2005                   4
# 5138                    1               2007                  52
# 7050                    2               2011                   0
# 7118                    1               2012                  29
# 8281                    1               2004                  33
# 9276                    1               2012                  42
# 12075                   2               2008                  23
# 13592                   0               2011                  13
# 17635                   1               2005                  33
# 18142                   1               2011                  28
# 19508                   1               2005                  38
# 19599                   1               2010                  37
# 19600                   1               2005                  28
# 20072                   1               2006                  19
# 20499                   2               2004                   4
# 26057                   2               2011                  24
# 27189                   2               2009                  26
# 29983                   0               2012                   2
# 39154                   2               2008                  37
# 39533                   1               2006                  23
# 40321                   2               2012                  30
# 41165                   2               2008                  24
# 41929                   1               2010                  14
# 42381                   1               2003                  11
# 43051                   2               2003                  21
# 43066                   1               2005                   9
# 43811                   2               2003                  45
# 43947                   0               2003                  16
# 44825                   1               2012                   4
# 45027                   1               2007                  24
# 46588                   2               2004                  10
# 46994                   1               2003                  52
# 47410                   2               2006                   6
# 47982                   2               2006                   9
# 50965                   2               2012                  14
# 51366                   1               2011                  37
# 55455                   1               2003                  36
# 60041                   1               2009                  68
# 62097                   2               2008                   4
# 62907                   1               2006                   0
# 74771                   2               2007                  27
# 84003                   1               2005                  22
# 84030                   1               2004                  33
# 85867                   1               2006                  34
# 86934                   0               2005                  52
# 119962                  1               2003                  26
# 121036                  1               2007                  15
# 125406                  1               2010                  36
#
#        no_of_flights_p.a._grouped  percentage_of_flight_with_other_airlines  \
# 249                      11 to 20                                         3
# 886                      11 to 20                                        10
# 1968                     31 to 40                                         9
# 2410                     41 to 50                                        10
# 2617                     81 to 90                                         9
# 3451                     11 to 20                                         7
# 3539                      1 to 10                                         9
# 3701                      1 to 10                                         5
# 3854                      1 to 10                                        21
# 5138                     51 to 60                                         6
# 7050                            0                                         5
# 7118                     21 to 30                                         6
# 8281                     31 to 40                                         7
# 9276                     41 to 50                                         9
# 12075                    21 to 30                                        19
# 13592                    11 to 20                                         5
# 17635                    31 to 40                                         3
# 18142                    21 to 30                                         1
# 19508                    31 to 40                                         7
# 19599                    31 to 40                                         2
# 19600                    21 to 30                                        15
# 20072                    11 to 20                                         2
# 20499                     1 to 10                                        13
# 26057                    21 to 30                                         8
# 27189                    21 to 30                                         3
# 29983                     1 to 10                                        10
# 39154                    31 to 40                                        10
# 39533                    21 to 30                                         6
# 40321                    21 to 30                                         1
# 41165                    21 to 30                                         7
# 41929                    11 to 20                                         6
# 42381                    11 to 20                                        19
# 43051                    21 to 30                                        13
# 43066                     1 to 10                                         3
# 43811                    41 to 50                                         2
# 43947                    11 to 20                                        10
# 44825                     1 to 10                                        98
# 45027                    21 to 30                                        12
# 46588                     1 to 10                                        20
# 46994                    51 to 60                                        10
# 47410                     1 to 10                                        25
# 47982                     1 to 10                                         8
# 50965                    11 to 20                                         4
# 51366                    31 to 40                                         2
# 55455                    31 to 40                                         7
# 60041                    61 to 70                                        10
# 62097                     1 to 10                                         8
# 62907                           0                                         9
# 74771                    21 to 30                                         5
# 84003                    21 to 30                                        10
# 84030                    31 to 40                                         2
# 85867                    31 to 40                                         9
# 86934                    51 to 60                                         9
# 119962                   21 to 30                                         9
# 121036                   11 to 20                                         1
# 125406                   31 to 40                                         6
#
#                    ...             departure_state          destination_city  \
# 249                ...                    Virginia             St. Louis, MO
# 886                ...                       Texas     Dallas/Fort Worth, TX
# 1968               ...                       Texas           Baton Rouge, LA
# 2410               ...                       Texas            Valparaiso, FL
# 2617               ...                       Texas             Texarkana, AR
# 3451               ...                        Ohio               Chicago, IL
# 3539               ...                North Dakota               Chicago, IL
# 3701               ...              North Carolina              New York, NY
# 3854               ...              North Carolina                 Miami, FL
# 5138               ...                    Maryland              New York, NY
# 7050               ...                    Illinois              Waterloo, IA
# 7118               ...                    Illinois            Fort Wayne, IN
# 8281               ...                     Florida              Key West, FL
# 9276               ...                    Virginia               Houston, TX
# 12075              ...                       Texas       Gulfport/Biloxi, MS
# 13592              ...                   Tennessee               Atlanta, GA
# 17635              ...                   Minnesota        Raleigh/Durham, NC
# 18142              ...                    Michigan                Bangor, ME
# 19508              ...                     Indiana               Atlanta, GA
# 19599              ...                    Illinois             Green Bay, WI
# 19600              ...                    Illinois              Appleton, WI
# 20072              ...                    Illinois              Syracuse, NY
# 20499              ...                    Illinois                Peoria, IL
# 26057              ...                     Georgia          Indianapolis, IN
# 27189              ...                  Washington               Kahului, HI
# 29983              ...                      Alaska                Juneau, AK
# 39154              ...                   Wisconsin           Minneapolis, MN
# 39533              ...                  Washington                Denver, CO
# 40321              ...                        Utah                 Butte, MT
# 41165              ...                       Texas  Harlingen/San Benito, TX
# 41929              ...                      Oregon               Seattle, WA
# 42381              ...                      Oregon         San Francisco, CA
# 43051              ...                      Nevada           Los Angeles, CA
# 43066              ...                      Nevada                Fresno, CA
# 43811              ...                   Minnesota             St. Louis, MO
# 43947              ...                   Minnesota               Bemidji, MN
# 44825              ...                    Illinois               Memphis, TN
# 45027              ...                    Illinois      Hancock/Houghton, MI
# 46588              ...                    Colorado                 Aspen, CO
# 46994              ...                    Colorado           Los Angeles, CA
# 47410              ...                  California        Salt Lake City, UT
# 47982              ...                  California              Portland, OR
# 50965              ...                  California           Los Angeles, CA
# 51366              ...                  California              Monterey, CA
# 55455              ...                Pennsylvania         San Francisco, CA
# 60041              ...                     Florida                Newark, NJ
# 62097              ...                  California              New York, NY
# 62907              ...                  California                Denver, CO
# 74771              ...                  California     Dallas/Fort Worth, TX
# 84003              ...                    Kentucky               Atlanta, GA
# 84030              ...                    Kentucky               Atlanta, GA
# 85867              ...                     Georgia          Philadelphia, PA
# 86934              ...                     Georgia       Gulfport/Biloxi, MS
# 119962             ...                       Texas               Phoenix, AZ
# 121036             ...                Pennsylvania       Fort Lauderdale, FL
# 125406             ...                    Illinois               Phoenix, AZ
#
#         destination_state  scheduled_departure_hour departure_delay_in_mins  \
# 249              Missouri                        20                    38.0
# 886                 Texas                        11                     0.0
# 1968            Louisiana                        16                     2.0
# 2410              Florida                        15                    58.0
# 2617             Arkansas                        15                     0.0
# 3451             Illinois                        19                     0.0
# 3539             Illinois                        11                    32.0
# 3701             New York                        10                   166.0
# 3854              Florida                        13                    22.0
# 5138             New York                        15                    14.0
# 7050                 Iowa                        15                    96.0
# 7118              Indiana                         8                     0.0
# 8281              Florida                        15                    17.0
# 9276                Texas                        17                    14.0
# 12075         Mississippi                        20                     0.0
# 13592             Georgia                        18                     8.0
# 17635      North Carolina                         8                   190.0
# 18142               Maine                        21                    33.0
# 19508             Georgia                        12                    60.0
# 19599           Wisconsin                         9                    24.0
# 19600           Wisconsin                        14                     0.0
# 20072            New York                        19                    20.0
# 20499            Illinois                        17                   121.0
# 26057             Indiana                        19                    98.0
# 27189              Hawaii                        11                    92.0
# 29983              Alaska                        20                    61.0
# 39154           Minnesota                         7                     1.0
# 39533            Colorado                        17                    45.0
# 40321             Montana                        22                     0.0
# 41165               Texas                        21                    16.0
# 41929          Washington                         9                     3.0
# 42381          California                        17                    51.0
# 43051          California                        16                     0.0
# 43066          California                        17                     5.0
# 43811            Missouri                         7                    15.0
# 43947           Minnesota                        21                     4.0
# 44825           Tennessee                         6                     0.0
# 45027            Michigan                        21                    42.0
# 46588            Colorado                        14                   131.0
# 46994          California                        19                   119.0
# 47410                Utah                        16                    42.0
# 47982              Oregon                        16                     0.0
# 50965          California                         7                     0.0
# 51366          California                         8                     0.0
# 55455          California                        18                   100.0
# 60041          New Jersey                        18                    40.0
# 62097            New York                         8                    31.0
# 62907            Colorado                        18                    54.0
# 74771               Texas                        10                    76.0
# 84003             Georgia                        18                     0.0
# 84030             Georgia                        18                    10.0
# 85867        Pennsylvania                         8                     0.0
# 86934         Mississippi                        10                    42.0
# 119962            Arizona                         8                     0.0
# 121036            Florida                        17                     2.0
# 125406            Arizona                        11                     0.0
#
#         arrival_delay_in_mins flight_cancelled flight_time_in_mins  \
# 249                       NaN              Yes                 NaN
# 886                       NaN              Yes                 NaN
# 1968                      NaN              Yes                 NaN
# 2410                      NaN              Yes                 NaN
# 2617                      NaN              Yes                 NaN
# 3451                      NaN              Yes                 NaN
# 3539                      NaN              Yes                 NaN
# 3701                      NaN              Yes                 NaN
# 3854                      NaN              Yes                 NaN
# 5138                      NaN              Yes                 NaN
# 7050                      NaN              Yes                 NaN
# 7118                      NaN              Yes                 NaN
# 8281                      NaN              Yes                 NaN
# 9276                      NaN              Yes                 NaN
# 12075                     NaN              Yes                 NaN
# 13592                     NaN              Yes                 NaN
# 17635                     NaN              Yes                 NaN
# 18142                     NaN              Yes                 NaN
# 19508                     NaN              Yes                 NaN
# 19599                     NaN              Yes                 NaN
# 19600                     NaN              Yes                 NaN
# 20072                     NaN              Yes                 NaN
# 20499                     NaN              Yes                 NaN
# 26057                     NaN              Yes                 NaN
# 27189                     NaN              Yes                 NaN
# 29983                     NaN              Yes                 NaN
# 39154                     NaN              Yes                 NaN
# 39533                     NaN              Yes                 NaN
# 40321                     NaN              Yes                 NaN
# 41165                     NaN              Yes                 NaN
# 41929                     NaN              Yes                 NaN
# 42381                     NaN              Yes                 NaN
# 43051                     NaN              Yes                 NaN
# 43066                     NaN              Yes                 NaN
# 43811                     NaN              Yes                 NaN
# 43947                     NaN              Yes                 NaN
# 44825                     NaN              Yes                 NaN
# 45027                     NaN              Yes                 NaN
# 46588                     NaN              Yes                 NaN
# 46994                     NaN              Yes                 NaN
# 47410                     NaN              Yes                 NaN
# 47982                     NaN              Yes                 NaN
# 50965                     NaN              Yes                 NaN
# 51366                     NaN              Yes                 NaN
# 55455                     NaN              Yes                 NaN
# 60041                     NaN              Yes                 NaN
# 62097                     NaN              Yes                 NaN
# 62907                     NaN              Yes                 NaN
# 74771                     NaN              Yes                 NaN
# 84003                     NaN              Yes                 NaN
# 84030                     NaN              Yes                 NaN
# 85867                     NaN              Yes                 NaN
# 86934                     NaN              Yes                 NaN
# 119962                    NaN              Yes                 NaN
# 121036                    NaN              Yes                 NaN
# 125406                    NaN              Yes                 NaN
#
#        flight_distance_in_miles arrival_delay_greater_5mins
# 249                         719                          no
# 886                         396                          no
# 1968                        383                          no
# 2410                        641                          no
# 2617                        181                          no
# 3451                        213                          no
# 3539                        557                          no
# 3701                        431                          no
# 3854                        650                          no
# 5138                        184                          no
# 7050                        234                          no
# 7118                        157                          no
# 8281                        125                          no
# 9276                       1201                          no
# 12075                       376                          no
# 13592                       152                          no
# 17635                       980                          no
# 18142                       750                          no
# 19508                       566                          no
# 19599                       173                          no
# 19600                       160                          no
# 20072                       607                          no
# 20499                       130                          no
# 26057                       432                          no
# 27189                      2681                          no
# 29983                       234                          no
# 39154                       190                          no
# 39533                      1024                          no
# 40321                       358                          no
# 41165                       295                          no
# 41929                       129                          no
# 42381                       550                          no
# 43051                       391                          no
# 43066                       259                          no
# 43811                       448                          no
# 43947                       199                          no
# 44825                       491                          no
# 45027                       359                          no
# 46588                       125                          no
# 46994                       833                          no
# 47410                       541                          no
# 47982                       834                          no
# 50965                       110                          no
# 51366                        77                          no
# 55455                      2521                          no
# 60041                      1023                          no
# 62097                      2475                          no
# 62907                       862                          no
# 74771                      1205                          no
# 84003                       373                          no
# 84030                       321                          no
# 85867                       666                          no
# 86934                       352                          no
# 119962                     1009                          no
# 121036                      992                          no
# 125406                     1440                          no
#
# [56 rows x 30 columns]

# %% [markdown]
# ### Processing of 2401 of missing values :
# #### Since those values are meaningful and there is no other applicable value to replace them, we have decided to let them as they are.

# %%
# flight is not cancelled but 'arrival_delay_in_mins' and 'flight_time_in_mins' are missing

data.loc[(data['flight_cancelled'] == 'No') 
         & ~(data['departure_delay_in_mins'].isnull()) 
         & (data['arrival_delay_in_mins'].isnull()) 
         & (data['flight_time_in_mins'].isnull())]

# There are still some Nan in 'arrival_delay_in_mins' and 'flight_time_in_mins' when the flight is not cancelled
# And these flights have been just delayed but we don't know if they have been arrived late or on time
# Hence, we are going to remove those rows with Nan values in 'arrival_delay_in_mins' and 'flight_time_in_mins'
# Out:
#        satisfaction membership_status  age age_range  gender  \
# 2451              3              Blue   63     60-69  Female
# 2681              2              Blue   45     40-49  Female
# 2757              3              Blue   72     70-79    Male
# 2864              2              Blue   72     70-79    Male
# 3640              5              Gold   35     30-39  Female
# 3641              5              Blue   44     40-49    Male
# 3713              3              Blue   85       80+  Female
# 4902              4              Blue   60     60-69    Male
# 5300              3              Blue   60     60-69  Female
# 5413              4            Silver   80       80+  Female
# 5980              4              Gold   43     40-49  Female
# 6313              4            Silver   32     30-39    Male
# 6559              4            Silver   58     50-59  Female
# 6591              3              Blue   16      0-19    Male
# 6696              3              Blue   16      0-19    Male
# 7724              4              Blue   48     40-49    Male
# 8011              4            Silver   61     60-69  Female
# 8509              4            Silver   47     40-49  Female
# 8524              3            Silver   39     30-39  Female
# 8525              2              Blue   44     40-49    Male
# 8754              5          Platinum   34     30-39  Female
# 8962              4              Blue   41     40-49  Female
# 9179              3            Silver   60     60-69    Male
# 9290              3          Platinum   63     60-69    Male
# 10133             4              Blue   30     30-39    Male
# 11038             3            Silver   46     40-49  Female
# 11787             2              Blue   68     60-69  Female
# 11847             5            Silver   39     30-39    Male
# 12044             5              Blue   34     30-39    Male
# 12627             3            Silver   59     50-59    Male
# ...             ...               ...  ...       ...     ...
# 119016            4            Silver   60     60-69    Male
# 120101            4              Blue   62     60-69    Male
# 120109            4              Blue   47     40-49    Male
# 120252            2              Blue   67     60-69  Female
# 120926            4            Silver   38     30-39  Female
# 121145            4              Blue   28     20-29    Male
# 121153            4            Silver   56     50-59  Female
# 121175            3              Blue   17      0-19    Male
# 121181            4              Blue   27     20-29    Male
# 121200            2              Blue   41     40-49  Female
# 121209            2              Blue   71     70-79    Male
# 123750            3            Silver   57     50-59    Male
# 124136            4              Blue   16      0-19    Male
# 124165            5              Gold   50     50-59    Male
# 125083            4            Silver   48     40-49    Male
# 125164            5            Silver   27     20-29  Female
# 125286            5            Silver   48     40-49    Male
# 125696            4            Silver   46     40-49    Male
# 125819            3              Blue   19      0-19  Female
# 126103            4              Gold   36     30-39  Female
# 127646            3              Blue   16      0-19    Male
# 128044            3              Blue   46     40-49  Female
# 128104            2              Blue   54     50-59    Male
# 128825            4              Blue   54     50-59  Female
# 128859            3              Blue   39     30-39  Female
# 129009            4              Blue   54     50-59    Male
# 129012            3              Blue   25     20-29  Female
# 129023            4              Blue   65     60-69  Female
# 129024            4              Blue   30     30-39  Female
# 129497            3              Blue   64     60-69  Female
#
#         price_sensitivity  first_flight_year  no_of_flights_p.a.  \
# 2451                    2               2008                  28
# 2681                    2               2007                  10
# 2757                    1               2009                  43
# 2864                    1               2004                  14
# 3640                    1               2006                   3
# 3641                    1               2005                  25
# 3713                    0               2012                  41
# 4902                    1               2011                  14
# 5300                    2               2009                  17
# 5413                    1               2005                  39
# 5980                    1               2010                  25
# 6313                    1               2012                  21
# 6559                    1               2007                  15
# 6591                    2               2003                  20
# 6696                    1               2008                  33
# 7724                    2               2003                  24
# 8011                    1               2008                  11
# 8509                    1               2008                   0
# 8524                    1               2008                   8
# 8525                    2               2003                  30
# 8754                    1               2007                   0
# 8962                    1               2010                   3
# 9179                    1               2009                   9
# 9290                    1               2012                  19
# 10133                   1               2012                  14
# 11038                   2               2006                  12
# 11787                   1               2011                  23
# 11847                   1               2010                   0
# 12044                   2               2008                  10
# 12627                   1               2007                  19
# ...                   ...                ...                 ...
# 119016                  1               2004                  36
# 120101                  1               2006                  38
# 120109                  1               2007                  23
# 120252                  2               2003                  34
# 120926                  1               2009                  41
# 121145                  1               2008                  19
# 121153                  2               2006                  13
# 121175                  1               2003                  17
# 121181                  1               2012                  18
# 121200                  1               2006                  10
# 121209                  1               2005                  23
# 123750                  1               2006                  14
# 124136                  3               2005                  18
# 124165                  1               2007                  22
# 125083                  1               2008                  14
# 125164                  1               2007                  21
# 125286                  1               2005                   5
# 125696                  3               2010                  23
# 125819                  2               2006                  13
# 126103                  2               2003                  38
# 127646                  2               2012                  25
# 128044                  1               2011                  22
# 128104                  1               2006                  46
# 128825                  2               2007                  33
# 128859                  1               2007                  17
# 129009                  2               2012                  26
# 129012                  2               2006                  23
# 129023                  1               2009                  39
# 129024                  1               2003                   8
# 129497                  1               2010                  25
#
#        no_of_flights_p.a._grouped  percentage_of_flight_with_other_airlines  \
# 2451                     21 to 30                                         6
# 2681                     11 to 20                                        23
# 2757                     41 to 50                                         5
# 2864                     11 to 20                                         7
# 3640                      1 to 10                                        33
# 3641                     21 to 30                                         3
# 3713                     41 to 50                                        10
# 4902                     11 to 20                                         4
# 5300                     11 to 20                                         1
# 5413                     31 to 40                                         1
# 5980                     21 to 30                                        10
# 6313                     21 to 30                                        11
# 6559                     11 to 20                                         3
# 6591                     11 to 20                                         8
# 6696                     31 to 40                                         8
# 7724                     21 to 30                                        10
# 8011                     11 to 20                                         7
# 8509                            0                                         5
# 8524                      1 to 10                                        18
# 8525                     31 to 40                                         2
# 8754                            0                                         8
# 8962                      1 to 10                                         6
# 9179                      1 to 10                                         7
# 9290                     11 to 20                                         5
# 10133                    11 to 20                                        18
# 11038                    11 to 20                                         4
# 11787                    21 to 30                                         3
# 11847                           0                                         3
# 12044                    11 to 20                                        10
# 12627                    11 to 20                                         6
# ...                           ...                                       ...
# 119016                   31 to 40                                         5
# 120101                   31 to 40                                         3
# 120109                   21 to 30                                         3
# 120252                   31 to 40                                         1
# 120926                   41 to 50                                         6
# 121145                   11 to 20                                        10
# 121153                   11 to 20                                         4
# 121175                   11 to 20                                         7
# 121181                   11 to 20                                        24
# 121200                   11 to 20                                        10
# 121209                   21 to 30                                         1
# 123750                   11 to 20                                         7
# 124136                   11 to 20                                         8
# 124165                   21 to 30                                         1
# 125083                   11 to 20                                         6
# 125164                   21 to 30                                         2
# 125286                    1 to 10                                         3
# 125696                   21 to 30                                         5
# 125819                   11 to 20                                         7
# 126103                   31 to 40                                        17
# 127646                   21 to 30                                        10
# 128044                   21 to 30                                         9
# 128104                   41 to 50                                         6
# 128825                   31 to 40                                         6
# 128859                   11 to 20                                        10
# 129009                   21 to 30                                         2
# 129012                   21 to 30                                        10
# 129023                   31 to 40                                         3
# 129024                    1 to 10                                         6
# 129497                   21 to 30                                         8
#
#                    ...             departure_state       destination_city  \
# 2451               ...                       Texas        Tallahassee, FL
# 2681               ...                       Texas         Montgomery, AL
# 2757               ...                   Tennessee  Dallas/Fort Worth, TX
# 2864               ...                   Tennessee            Chicago, IL
# 3640               ...              North Carolina           New York, NY
# 3641               ...              North Carolina           New York, NY
# 3713               ...              North Carolina           New York, NY
# 4902               ...                   Minnesota           New York, NY
# 5300               ...                   Louisiana  Dallas/Fort Worth, TX
# 5413               ...                    Kentucky  Dallas/Fort Worth, TX
# 5980               ...                    Illinois  Dallas/Fort Worth, TX
# 6313               ...                    Illinois             Dayton, OH
# 6559               ...                    Illinois          Watertown, NY
# 6591               ...                    Illinois          Watertown, NY
# 6696               ...                    Illinois        Springfield, MO
# 7724               ...                     Florida            Memphis, TN
# 8011               ...                     Florida       Jacksonville, FL
# 8509               ...                  California              Aspen, CO
# 8524               ...                  California              Aspen, CO
# 8525               ...                  California              Aspen, CO
# 8754               ...                    Arkansas           New York, NY
# 8962               ...                   Wisconsin           New York, NY
# 9179               ...               West Virginia            Chicago, IL
# 9290               ...                    Virginia            Houston, TX
# 10133              ...                       Texas  Charleston/Dunbar, WV
# 11038              ...                       Texas  Dallas/Fort Worth, TX
# 11787              ...                       Texas              Tulsa, OK
# 11847              ...                       Texas          Charlotte, NC
# 12044              ...                       Texas    Gulfport/Biloxi, MS
# 12627              ...                       Texas       Indianapolis, IN
# ...                ...                         ...                    ...
# 119016             ...                     Alabama              Tampa, FL
# 120101             ...                 Puerto Rico       Philadelphia, PA
# 120109             ...                 Puerto Rico       Philadelphia, PA
# 120252             ...                Pennsylvania            Houston, TX
# 120926             ...                Pennsylvania              Tampa, FL
# 121145             ...                Pennsylvania          San Diego, CA
# 121153             ...                Pennsylvania      San Francisco, CA
# 121175             ...                Pennsylvania      San Francisco, CA
# 121181             ...                Pennsylvania          San Diego, CA
# 121200             ...                Pennsylvania      San Francisco, CA
# 121209             ...                Pennsylvania      San Francisco, CA
# 123750             ...                    New York       Philadelphia, PA
# 124136             ...                  New Jersey          Charlotte, NC
# 124165             ...                  New Jersey            Phoenix, AZ
# 125083             ...                    Maryland          Charlotte, NC
# 125164             ...                       Maine          Charlotte, NC
# 125286             ...                    Illinois       Philadelphia, PA
# 125696             ...                     Florida         Washington, DC
# 125819             ...                     Florida       Philadelphia, PA
# 126103             ...                     Florida          Charlotte, NC
# 127646             ...                     Arizona          Charlotte, NC
# 128044             ...                     Arizona            Chicago, IL
# 128104             ...                     Arizona           Honolulu, HI
# 128825             ...                    New York        Los Angeles, CA
# 128859             ...                    New York        Los Angeles, CA
# 129009             ...               Massachusetts      San Francisco, CA
# 129012             ...               Massachusetts      San Francisco, CA
# 129023             ...               Massachusetts      San Francisco, CA
# 129024             ...               Massachusetts        Los Angeles, CA
# 129497             ...                  California             Boston, MA
#
#         destination_state  scheduled_departure_hour departure_delay_in_mins  \
# 2451              Florida                        18                     5.0
# 2681              Alabama                        20                   109.0
# 2757                Texas                         6                     0.0
# 2864             Illinois                        16                    15.0
# 3640             New York                         6                     0.0
# 3641             New York                        18                     6.0
# 3713             New York                         6                     0.0
# 4902             New York                        17                   118.0
# 5300                Texas                        18                     0.0
# 5413                Texas                        18                     0.0
# 5980                Texas                        18                     0.0
# 6313                 Ohio                        22                    70.0
# 6559             New York                        18                     0.0
# 6591             New York                        18                    48.0
# 6696             Missouri                        19                     0.0
# 7724            Tennessee                        10                     0.0
# 8011              Florida                        16                     0.0
# 8509             Colorado                         9                    12.0
# 8524             Colorado                         9                     0.0
# 8525             Colorado                         9                     0.0
# 8754             New York                        18                     0.0
# 8962             New York                        11                     0.0
# 9179             Illinois                         5                   266.0
# 9290                Texas                        21                   198.0
# 10133       West Virginia                        13                     0.0
# 11038               Texas                         7                    11.0
# 11787            Oklahoma                        14                    15.0
# 11847      North Carolina                        18                   127.0
# 12044         Mississippi                         9                     0.0
# 12627             Indiana                         7                     0.0
# ...                   ...                       ...                     ...
# 119016            Florida                        17                     2.0
# 120101       Pennsylvania                        13                   115.0
# 120109       Pennsylvania                        13                     0.0
# 120252              Texas                        13                     0.0
# 120926            Florida                         9                    29.0
# 121145         California                        16                    60.0
# 121153         California                        10                    72.0
# 121175         California                        20                     0.0
# 121181         California                        17                     3.0
# 121200         California                         7                     0.0
# 121209         California                        10                   107.0
# 123750       Pennsylvania                        15                    16.0
# 124136     North Carolina                         6                     0.0
# 124165            Arizona                        16                    63.0
# 125083     North Carolina                        13                    23.0
# 125164     North Carolina                         7                    41.0
# 125286       Pennsylvania                         7                     0.0
# 125696           Virginia                         8                     0.0
# 125819       Pennsylvania                         7                     0.0
# 126103     North Carolina                         6                     0.0
# 127646     North Carolina                         9                     0.0
# 128044           Illinois                        13                     0.0
# 128104             Hawaii                        18                     2.0
# 128825         California                         9                     0.0
# 128859         California                        16                    29.0
# 129009         California                         8                     7.0
# 129012         California                         9                     0.0
# 129023         California                         9                     0.0
# 129024         California                         7                     8.0
# 129497      Massachusetts                         9                     0.0
#
#         arrival_delay_in_mins flight_cancelled flight_time_in_mins  \
# 2451                      NaN               No                 NaN
# 2681                      NaN               No                 NaN
# 2757                      NaN               No                 NaN
# 2864                      NaN               No                 NaN
# 3640                      NaN               No                 NaN
# 3641                      NaN               No                 NaN
# 3713                      NaN               No                 NaN
# 4902                      NaN               No                 NaN
# 5300                      NaN               No                 NaN
# 5413                      NaN               No                 NaN
# 5980                      NaN               No                 NaN
# 6313                      NaN               No                 NaN
# 6559                      NaN               No                 NaN
# 6591                      NaN               No                 NaN
# 6696                      NaN               No                 NaN
# 7724                      NaN               No                 NaN
# 8011                      NaN               No                 NaN
# 8509                      NaN               No                 NaN
# 8524                      NaN               No                 NaN
# 8525                      NaN               No                 NaN
# 8754                      NaN               No                 NaN
# 8962                      NaN               No                 NaN
# 9179                      NaN               No                 NaN
# 9290                      NaN               No                 NaN
# 10133                     NaN               No                 NaN
# 11038                     NaN               No                 NaN
# 11787                     NaN               No                 NaN
# 11847                     NaN               No                 NaN
# 12044                     NaN               No                 NaN
# 12627                     NaN               No                 NaN
# ...                       ...              ...                 ...
# 119016                    NaN               No                 NaN
# 120101                    NaN               No                 NaN
# 120109                    NaN               No                 NaN
# 120252                    NaN               No                 NaN
# 120926                    NaN               No                 NaN
# 121145                    NaN               No                 NaN
# 121153                    NaN               No                 NaN
# 121175                    NaN               No                 NaN
# 121181                    NaN               No                 NaN
# 121200                    NaN               No                 NaN
# 121209                    NaN               No                 NaN
# 123750                    NaN               No                 NaN
# 124136                    NaN               No                 NaN
# 124165                    NaN               No                 NaN
# 125083                    NaN               No                 NaN
# 125164                    NaN               No                 NaN
# 125286                    NaN               No                 NaN
# 125696                    NaN               No                 NaN
# 125819                    NaN               No                 NaN
# 126103                    NaN               No                 NaN
# 127646                    NaN               No                 NaN
# 128044                    NaN               No                 NaN
# 128104                    NaN               No                 NaN
# 128825                    NaN               No                 NaN
# 128859                    NaN               No                 NaN
# 129009                    NaN               No                 NaN
# 129012                    NaN               No                 NaN
# 129023                    NaN               No                 NaN
# 129024                    NaN               No                 NaN
# 129497                    NaN               No                 NaN
#
#        flight_distance_in_miles arrival_delay_greater_5mins
# 2451                        767                          no
# 2681                        622                          no
# 2757                        772                          no
# 2864                        475                          no
# 3640                        427                          no
# 3641                        431                          no
# 3713                        427                          no
# 4902                       1020                          no
# 5300                        285                          no
# 5413                        785                          no
# 5980                        691                          no
# 6313                        240                          no
# 6559                        618                          no
# 6591                        618                          no
# 6696                        438                          no
# 7724                        859                          no
# 8011                        335                          no
# 8509                        737                          no
# 8524                        737                          no
# 8525                        737                          no
# 8754                       1147                          no
# 8962                        738                          no
# 9179                        416                          no
# 9290                       1190                          no
# 10133                       946                          no
# 11038                       224                          no
# 11787                       429                          no
# 11847                       912                          no
# 12044                       376                          no
# 12627                       844                          no
# ...                         ...                         ...
# 119016                      459                          no
# 120101                     1576                          no
# 120109                     1576                          no
# 120252                     1325                          no
# 120926                      920                          no
# 121145                     2370                          no
# 121153                     2521                          no
# 121175                     2521                          no
# 121181                     2370                          no
# 121200                     2521                          no
# 121209                     2521                          no
# 123750                       96                          no
# 124136                      529                          no
# 124165                     2133                          no
# 125083                      361                          no
# 125164                      813                          no
# 125286                      678                          no
# 125696                      759                          no
# 125819                     1013                          no
# 126103                      328                          no
# 127646                     1773                          no
# 128044                     1440                          no
# 128104                     2917                          no
# 128825                     2475                          no
# 128859                     2475                          no
# 129009                     2704                          no
# 129012                     2704                          no
# 129023                     2704                          no
# 129024                     2611                          no
# 129497                     2704                          no
#
# [337 rows x 30 columns]

# %%
# Drop the rows

data.drop(data.loc[(data['flight_cancelled'] == 'No') 
         & ~(data['departure_delay_in_mins'].isnull()) 
         & (data['arrival_delay_in_mins'].isnull()) 
         & (data['flight_time_in_mins'].isnull())].index, inplace=True)

data.head(10)
# Out:
#   satisfaction membership_status  age age_range  gender  price_sensitivity  \
# 0          4.5              Blue   31     30-39    Male                  1
# 1            4              Blue   56     50-59    Male                  2
# 2          2.5              Blue   21     20-29  Female                  2
# 3            4              Blue   43     40-49    Male                  1
# 4            5            Silver   49     40-49    Male                  1
# 5            5              Gold   49     40-49  Female                  1
# 6          3.5              Gold   35     30-39    Male                  1
# 7            4            Silver   33     30-39    Male                  1
# 8            4              Blue   44     40-49  Female                  1
# 9            4              Blue   51     50-59  Female                  1
#
#    first_flight_year  no_of_flights_p.a. no_of_flights_p.a._grouped  \
# 0               2007                  28                   21 to 30
# 1               2006                  41                   41 to 50
# 2               2006                   8                    1 to 10
# 3               2007                   9                    1 to 10
# 4               2006                  14                   11 to 20
# 5               2010                   0                    1 to 10
# 6               2011                  15                   11 to 20
# 7               2010                   4                    1 to 10
# 8               2003                   8                    1 to 10
# 9               2005                  12                   11 to 20
#
#    percentage_of_flight_with_other_airlines             ...              \
# 0                                         7             ...
# 1                                         3             ...
# 2                                         7             ...
# 3                                         9             ...
# 4                                        10             ...
# 5                                         4             ...
# 6                                         5             ...
# 7                                        17             ...
# 8                                         6             ...
# 9                                         7             ...
#
#   departure_state       destination_city  destination_state  \
# 0       Wisconsin  Dallas/Fort Worth, TX              Texas
# 1       Wisconsin  Dallas/Fort Worth, TX              Texas
# 2       Wisconsin  Dallas/Fort Worth, TX              Texas
# 3       Wisconsin  Dallas/Fort Worth, TX              Texas
# 4       Wisconsin  Dallas/Fort Worth, TX              Texas
# 5       Wisconsin  Dallas/Fort Worth, TX              Texas
# 6       Wisconsin  Dallas/Fort Worth, TX              Texas
# 7       Wisconsin  Dallas/Fort Worth, TX              Texas
# 8       Wisconsin  Dallas/Fort Worth, TX              Texas
# 9       Wisconsin  Dallas/Fort Worth, TX              Texas
#
#    scheduled_departure_hour departure_delay_in_mins  arrival_delay_in_mins  \
# 0                        15                     0.0                    3.0
# 1                        11                     2.0                    5.0
# 2                        12                    34.0                   14.0
# 3                        11                    26.0                   39.0
# 4                        12                     0.0                    0.0
# 5                        18                     0.0                    0.0
# 6                         6                     0.0                    0.0
# 7                        18                     0.0                    1.0
# 8                        12                     0.0                    0.0
# 9                        18                     0.0                    0.0
#
#   flight_cancelled flight_time_in_mins flight_distance_in_miles  \
# 0               No               134.0                      821
# 1               No               120.0                      821
# 2               No               122.0                      853
# 3               No               141.0                      821
# 4               No               144.0                      853
# 5               No               123.0                      821
# 6               No               119.0                      821
# 7               No               138.0                      821
# 8               No               114.0                      853
# 9               No               118.0                      821
#
#   arrival_delay_greater_5mins
# 0                          no
# 1                          no
# 2                         yes
# 3                         yes
# 4                          no
# 5                          no
# 6                          no
# 7                          no
# 8                          no
# 9                          no
#
# [10 rows x 30 columns]

# %% [markdown]
# ## 3.2 Feature conversions
# ### 3.2.1 Object to float: 'satisfaction'

# %%
data['satisfaction'] = data['satisfaction'].astype('float64')  

# there are the rows which have incorrect values such as 4.002.00
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-1e283f0fd42f> in <module>()
# ----> 1 data['satisfaction'] = data['satisfaction'].astype('float64')
#       2
#       3 # there are the rows which have incorrect values such as 4.002.00
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4002         # else, only a single dtype is given
#    4003         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4004                                      **kwargs)
#    4005         return self._constructor(new_data).__finalize__(self)
#    4006
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in astype(self, dtype, **kwargs)
#    3460
#    3461     def astype(self, dtype, **kwargs):
# -> 3462         return self.apply('astype', dtype=dtype, **kwargs)
#    3463
#    3464     def convert(self, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3327
#    3328             kwargs['mgr'] = self
# -> 3329             applied = getattr(b, f)(**kwargs)
#    3330             result_blocks = _extend_blocks(applied, result_blocks)
#    3331
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in astype(self, dtype, copy, errors, values, **kwargs)
#     542     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     543         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 544                             **kwargs)
#     545
#     546     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in _astype(self, dtype, copy, errors, values, klass, mgr, **kwargs)
#     623
#     624                 # _astype_nansafe works fine with 1-d only
# --> 625                 values = astype_nansafe(values.ravel(), dtype, copy=True)
#     626                 values = values.reshape(self.shape)
#     627
#
# ~\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy)
#     701
#     702     if copy:
# --> 703         return arr.astype(dtype)
#     704     return arr.view(dtype)
#     705
#
# ValueError: could not convert string to float: '4.00.2.00'

# %%
# check unique value of variable 'satisfaction'
data['satisfaction'].unique()

# there are rows with incorrect values such as '4.00.5' and '4.00.2.00'
etrange = ['4.00.5', '4.00.2.00']

# check which rows have those values
data.loc[data['satisfaction'].isin(etrange)]
# Out:
#       satisfaction membership_status  age age_range  gender  \
# 38897       4.00.5            Silver   36     30-39    Male
# 38898    4.00.2.00            Silver   54     50-59  Female
# 38899    4.00.2.00              Blue   42     40-49    Male
#
#        price_sensitivity  first_flight_year  no_of_flights_p.a.  \
# 38897                  2               2010                  18
# 38898                  3               2006                   0
# 38899                  1               2011                   6
#
#       no_of_flights_p.a._grouped  percentage_of_flight_with_other_airlines  \
# 38897                   11 to 20                                        15
# 38898                          0                                         6
# 38899                    1 to 10                                         3
#
#                   ...             departure_state    destination_city  \
# 38897             ...                     Wyoming  Salt Lake City, UT
# 38898             ...                     Wyoming  Salt Lake City, UT
# 38899             ...                     Wyoming  Salt Lake City, UT
#
#        destination_state  scheduled_departure_hour departure_delay_in_mins  \
# 38897               Utah                         6                     0.0
# 38898               Utah                        12                     1.0
# 38899               Utah                        13                     0.0
#
#        arrival_delay_in_mins flight_cancelled flight_time_in_mins  \
# 38897                    0.0               No                43.0
# 38898                    0.0               No                59.0
# 38899                    0.0               No                39.0
#
#       flight_distance_in_miles arrival_delay_greater_5mins
# 38897                      162                          no
# 38898                      320                          no
# 38899                      205                          no
#
# [3 rows x 30 columns]

# %%
# remove those rows
data.drop(data.loc[data['satisfaction'].isin(etrange)].index, inplace=True)

data['satisfaction'].unique()
# Out:
# array(['4.5', '4', '2.5', '5', '3.5', '2', '3', '1'], dtype=object)

# %%
# alter the type of the variable, 'satisfaction'
data['satisfaction'] = data['satisfaction'].astype('float64')

data.describe()
# Out:
#         satisfaction            age  price_sensitivity  first_flight_year  \
# count  129549.000000  129549.000000      129549.000000      129549.000000
# mean        3.379192      46.196034           1.275479        2007.208207
# std         0.964707      17.320021           0.546370           2.976941
# min         1.000000      15.000000           0.000000        2003.000000
# 25%         3.000000      33.000000           1.000000        2004.000000
# 50%         4.000000      45.000000           1.000000        2007.000000
# 75%         4.000000      58.000000           2.000000        2010.000000
# max         5.000000      85.000000           5.000000        2012.000000
#
#        no_of_flights_p.a.  percentage_of_flight_with_other_airlines  \
# count       129549.000000                             129549.000000
# mean            20.080317                                  9.317339
# std             14.384130                                  8.764194
# min              0.000000                                  1.000000
# 25%              9.000000                                  4.000000
# 50%             17.000000                                  7.000000
# 75%             29.000000                                 10.000000
# max            100.000000                                110.000000
#
#        no_of_other_loyalty_cards  shopping_amount_at_airport  \
# count              129549.000000               129549.000000
# mean                    0.883689                   26.565662
# std                     1.142249                   53.102866
# min                     0.000000                    0.000000
# 25%                     0.000000                    0.000000
# 50%                     0.000000                    0.000000
# 75%                     2.000000                   30.000000
# max                    12.000000                  879.000000
#
#        eating_and_drinking_at_airport   day_of_month  \
# count                   129549.000000  129549.000000
# mean                        68.240264      15.726204
# std                         52.222125       8.656782
# min                          0.000000       1.000000
# 25%                         30.000000       8.000000
# 50%                         60.000000      16.000000
# 75%                         90.000000      23.000000
# max                        895.000000      31.000000
#
#        scheduled_departure_hour  departure_delay_in_mins  \
# count             129549.000000            127204.000000
# mean                  12.987009                14.922455
# std                    4.623056                38.233513
# min                    1.000000                 0.000000
# 25%                    9.000000                 0.000000
# 50%                   13.000000                 0.000000
# 75%                   17.000000                13.000000
# max                   23.000000              1592.000000
#
#        arrival_delay_in_mins  flight_time_in_mins  flight_distance_in_miles
# count          127148.000000        127148.000000             129549.000000
# mean               15.369058           111.515848                793.327868
# std                38.762799            71.776047                591.771380
# min                 0.000000             8.000000                 31.000000
# 25%                 0.000000            59.000000                362.000000
# 50%                 0.000000            92.000000                628.000000
# 75%                13.000000           142.000000               1024.000000
# max              1584.000000           669.000000               4983.000000

# %% [markdown]
# ### 3.2.2 String to datetime: 'flight_date'

# %%
data['flight_date'] = pd.to_datetime(data['flight_date'])

 # drop the column that we don't need
data.drop(['day_of_month'], inplace=True, axis=1)

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129549 entries, 0 to 129888
# Data columns (total 29 columns):
# satisfaction                                129549 non-null float64
# membership_status                           129549 non-null object
# age                                         129549 non-null int64
# age_range                                   129549 non-null object
# gender                                      129549 non-null object
# price_sensitivity                           129549 non-null int64
# first_flight_year                           129549 non-null int64
# no_of_flights_p.a.                          129549 non-null int64
# no_of_flights_p.a._grouped                  129549 non-null object
# percentage_of_flight_with_other_airlines    129549 non-null int64
# travel_type                                 129549 non-null object
# no_of_other_loyalty_cards                   129549 non-null int64
# shopping_amount_at_airport                  129549 non-null int64
# eating_and_drinking_at_airport              129549 non-null int64
# cabin_class                                 129549 non-null object
# flight_date                                 129549 non-null datetime64[ns]
# airline_code                                129549 non-null object
# airline_name                                129549 non-null object
# departure_city                              129549 non-null object
# departure_state                             129549 non-null object
# destination_city                            129549 non-null object
# destination_state                           129549 non-null object
# scheduled_departure_hour                    129549 non-null int64
# departure_delay_in_mins                     127204 non-null float64
# arrival_delay_in_mins                       127148 non-null float64
# flight_cancelled                            129549 non-null object
# flight_time_in_mins                         127148 non-null float64
# flight_distance_in_miles                    129549 non-null int64
# arrival_delay_greater_5mins                 129549 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(10), object(14)
# memory usage: 29.7+ MB

# %%
# check the unique value of the flight year

data['flight_date'].dt.year.unique()
# Out:
# array([2014], dtype=int64)

# %%
## I need to check....
#data.loc[(data['No of Flights p.a.'] == 0)
#         & (data['No of Flights p.a. grouped'] != '0')]

# %% [markdown]
# ## 3.3 Feature creation
# ### 3.3.1 Create a column: 'total_delay_in_mins'

# %%
data['total_delay_in_mins'] = data['departure_delay_in_mins'] + data['arrival_delay_in_mins']

data.total_delay_in_mins.isnull().sum()
# Out:
# 2401

# %% [markdown]
# ### 3.3.2 Create a column: 'flight_status'

# %%
data['flight_status'] = np.where(data['total_delay_in_mins'] == 0, 'ontime',
        (np.where(data['total_delay_in_mins'] > 0, 'delayed', 
        (np.where((data['total_delay_in_mins'].isnull()) & (data['flight_cancelled'] == 'No'), 'delayed',
        (np.where((data['total_delay_in_mins'].isnull()) & (data['flight_cancelled'] == 'Yes'), 'cancelled', '')))))))
 
data.flight_status.value_counts()
# Out:
# delayed      70139
# ontime       57009
# cancelled     2401
# Name: flight_status, dtype: int64

# %%
# drop the column that we don't need
data.drop(['flight_cancelled'], inplace=True, axis=1) 

data.tail(10)
# Out:
#         satisfaction membership_status  age age_range  gender  \
# 129879           3.0              Blue   23     20-29  Female
# 129880           4.0            Silver   32     30-39  Female
# 129881           1.0              Blue   60     60-69  Female
# 129882           3.0              Blue   85       80+    Male
# 129883           2.0              Blue   15      0-19  Female
# 129884           2.0              Blue   85       80+  Female
# 129885           2.0              Blue   16      0-19  Female
# 129886           2.0              Blue   78     70-79  Female
# 129887           4.0              Gold   48     40-49    Male
# 129888           3.0              Blue   59     50-59  Female
#
#         price_sensitivity  first_flight_year  no_of_flights_p.a.  \
# 129879                  2               2005                  11
# 129880                  1               2010                  16
# 129881                  1               2005                  20
# 129882                  1               2011                  46
# 129883                  1               2007                   9
# 129884                  1               2011                  29
# 129885                  1               2011                  14
# 129886                  1               2003                  19
# 129887                  1               2006                  10
# 129888                  1               2011                  16
#
#        no_of_flights_p.a._grouped  percentage_of_flight_with_other_airlines  \
# 129879                   11 to 20                                        32
# 129880                   11 to 20                                         9
# 129881                   11 to 20                                         4
# 129882                   41 to 50                                        10
# 129883                    1 to 10                                         6
# 129884                   21 to 30                                         4
# 129885                   11 to 20                                         7
# 129886                   11 to 20                                         5
# 129887                   11 to 20                                         8
# 129888                   11 to 20                                         2
#
#             ...        destination_city  destination_state  \
# 129879      ...       San Francisco, CA         California
# 129880      ...         Los Angeles, CA         California
# 129881      ...         Los Angeles, CA         California
# 129882      ...         Los Angeles, CA         California
# 129883      ...         Los Angeles, CA         California
# 129884      ...           San Diego, CA         California
# 129885      ...         Los Angeles, CA         California
# 129886      ...       San Francisco, CA         California
# 129887      ...       San Francisco, CA         California
# 129888      ...       San Francisco, CA         California
#
#         scheduled_departure_hour  departure_delay_in_mins  \
# 129879                        18                     46.0
# 129880                        17                      0.0
# 129881                         6                      0.0
# 129882                        15                      0.0
# 129883                        19                      0.0
# 129884                        19                      2.0
# 129885                        14                      0.0
# 129886                         7                      6.0
# 129887                         9                     31.0
# 129888                         7                      0.0
#
#        arrival_delay_in_mins flight_time_in_mins flight_distance_in_miles  \
# 129879                  58.0                56.0                      337
# 129880                   1.0                56.0                      337
# 129881                  22.0                73.0                      308
# 129882                   0.0                56.0                      337
# 129883                   0.0                49.0                      308
# 129884                   3.0                69.0                      447
# 129885                   0.0                53.0                      308
# 129886                  14.0                72.0                      337
# 129887                  22.0                56.0                      337
# 129888                   0.0                59.0                      337
#
#        arrival_delay_greater_5mins total_delay_in_mins flight_status
# 129879                         yes               104.0       delayed
# 129880                          no                 1.0       delayed
# 129881                         yes                22.0       delayed
# 129882                          no                 0.0        ontime
# 129883                          no                 0.0        ontime
# 129884                          no                 5.0       delayed
# 129885                          no                 0.0        ontime
# 129886                         yes                20.0       delayed
# 129887                         yes                53.0       delayed
# 129888                          no                 0.0        ontime
#
# [10 rows x 30 columns]

# %% [markdown]
# ### 3.3.2 Create a column: 'country'

# %%
# in order to have a geographic map, we need to have a column for the country
data['country'] = 'United States'
# Out:
#    satisfaction membership_status  age age_range  gender  price_sensitivity  \
# 0           4.5              Blue   31     30-39    Male                  1
# 1           4.0              Blue   56     50-59    Male                  2
# 2           2.5              Blue   21     20-29  Female                  2
# 3           4.0              Blue   43     40-49    Male                  1
# 4           5.0            Silver   49     40-49    Male                  1
# 5           5.0              Gold   49     40-49  Female                  1
# 6           3.5              Gold   35     30-39    Male                  1
# 7           4.0            Silver   33     30-39    Male                  1
# 8           4.0              Blue   44     40-49  Female                  1
# 9           4.0              Blue   51     50-59  Female                  1
#
#    first_flight_year  no_of_flights_p.a. no_of_flights_p.a._grouped  \
# 0               2007                  28                   21 to 30
# 1               2006                  41                   41 to 50
# 2               2006                   8                    1 to 10
# 3               2007                   9                    1 to 10
# 4               2006                  14                   11 to 20
# 5               2010                   0                    1 to 10
# 6               2011                  15                   11 to 20
# 7               2010                   4                    1 to 10
# 8               2003                   8                    1 to 10
# 9               2005                  12                   11 to 20
#
#    percentage_of_flight_with_other_airlines      ...       destination_state  \
# 0                                         7      ...                   Texas
# 1                                         3      ...                   Texas
# 2                                         7      ...                   Texas
# 3                                         9      ...                   Texas
# 4                                        10      ...                   Texas
# 5                                         4      ...                   Texas
# 6                                         5      ...                   Texas
# 7                                        17      ...                   Texas
# 8                                         6      ...                   Texas
# 9                                         7      ...                   Texas
#
#    scheduled_departure_hour  departure_delay_in_mins  arrival_delay_in_mins  \
# 0                        15                      0.0                    3.0
# 1                        11                      2.0                    5.0
# 2                        12                     34.0                   14.0
# 3                        11                     26.0                   39.0
# 4                        12                      0.0                    0.0
# 5                        18                      0.0                    0.0
# 6                         6                      0.0                    0.0
# 7                        18                      0.0                    1.0
# 8                        12                      0.0                    0.0
# 9                        18                      0.0                    0.0
#
#   flight_time_in_mins flight_distance_in_miles arrival_delay_greater_5mins  \
# 0               134.0                      821                          no
# 1               120.0                      821                          no
# 2               122.0                      853                         yes
# 3               141.0                      821                         yes
# 4               144.0                      853                          no
# 5               123.0                      821                          no
# 6               119.0                      821                          no
# 7               138.0                      821                          no
# 8               114.0                      853                          no
# 9               118.0                      821                          no
#
#   total_delay_in_mins flight_status        country
# 0                 3.0       delayed  United States
# 1                 7.0       delayed  United States
# 2                48.0       delayed  United States
# 3                65.0       delayed  United States
# 4                 0.0        ontime  United States
# 5                 0.0        ontime  United States
# 6                 0.0        ontime  United States
# 7                 1.0       delayed  United States
# 8                 0.0        ontime  United States
# 9                 0.0        ontime  United States
#
# [10 rows x 31 columns]

# %%
# for variables 'departure_city' and 'destination_city', we only filter the info of city 
data['departure_city'] = data['departure_city'].str.split(',', expand=True)[0]
data['destination_city'] = data['destination_city'].str.split(',', expand=True)[0]

# %% [markdown]
# # 4. EDA

# %% [markdown]
# ## 4.1 Histogram

# %%
# other continuous variables which don't have nan values

cont = ['age', 'shopping_amount_at_airport', 'eating_and_drinking_at_airport']

cnt=0
plt.figure(figsize=(10, 10)).subplots_adjust(hspace=0.5)
for i in cont:
    cnt += 1
    plt.subplot(3, 1, cnt)
    plt.hist(data[i])
    plt.title(i, size = 15)
plt.show()

# %%
# extract the rows which don't have Nan values
# if not, we cannot have a histogram

notnull_departure = data[~np.isnan(data['departure_delay_in_mins'])]
notnull_arrival = data[~np.isnan(data['arrival_delay_in_mins'])]
notnull_flighttime = data[~np.isnan(data['flight_time_in_mins'])]
notnull_total_delay = data[~np.isnan(data['total_delay_in_mins'])]

# %%
# delay time related variables

plt.figure(figsize=(18, 6)).subplots_adjust(hspace=0.3)

plt.subplot(2, 2, 1)
plt.hist(notnull_departure['departure_delay_in_mins'])
plt.title('Departure Delay Time Histogram', size = 15)

plt.subplot(2, 2, 2)
plt.hist(notnull_arrival['arrival_delay_in_mins'])
plt.title('Arrival Delay Time Histogram', size = 15)

plt.subplot(2, 2, 3)
plt.hist(notnull_flighttime['flight_time_in_mins'])
plt.title('Flight Time Histogram', size = 15)

plt.subplot(2, 2, 4)
plt.hist(notnull_flighttime['total_delay_in_mins'])
plt.title('Total Delay Time Histogram', size = 15)
plt.show()

# %% [markdown]
# ## 4.2 Boxplot

# %%
# other continuous variables which don't have nan values
cnt = 0

plt.figure(figsize=(15, 5)).subplots_adjust(hspace=0.4, wspace=0.3)
for i in cont:
    cnt += 1
    plt.subplot(1, 3, cnt)
    sns.boxplot(y=data[i])
    plt.title(i, size = 15)
plt.show()

# %%
# delay time related variables

plt.figure(figsize=(20, 6)).subplots_adjust(hspace=0.4, wspace=0.3)

plt.subplot(1, 4, 1)
sns.boxplot(y=notnull_departure['departure_delay_in_mins'])
plt.title('Departure Delay Time', size = 15)

plt.subplot(1, 4, 2)
sns.boxplot(y=notnull_arrival['arrival_delay_in_mins'])
plt.title('Arrival Delay Time', size = 15)

plt.subplot(1, 4, 3)
sns.boxplot(y=notnull_arrival['total_delay_in_mins'])
plt.title('Total Delay Time', size = 15)

plt.subplot(1, 4, 4)
sns.boxplot(y=notnull_flighttime['flight_time_in_mins'])
plt.title('Flight Time', size = 15)
plt.show()

# %% [markdown]
# ### Processing of Outliers :
# #### As you can see, we observe some amount of outliers in most of continuous variables. Since those outliers seemes to be happened in real life (not written by mistake), we have decided to keep those values as they are. For instance, 'depature delay time' is in minutes, so even the longest time,1592 mins, is about one day. It's rare but it's happening (It has already happened to me).

# %% [markdown]
# # 5. Create a csv file for Data Visualization

# %%
data.to_csv('airline_processed2.csv', sep=',', index=False)
